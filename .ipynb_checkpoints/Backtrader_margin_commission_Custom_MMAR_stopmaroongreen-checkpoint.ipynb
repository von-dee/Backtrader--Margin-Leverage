# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt
import backtrader.feeds as btfeed




class setUpTrigger():
    
    def __init__(self, ma05, ma10, ma15, ma20, ma25, ma30, ma35, ma40, ma45, ma50, ma55, ma60, ma65, ma70, ma75, ma80, ma85, ma90, ma100):
        self.ma05 = ma05
        self.ma10 = ma10
        self.ma15 = ma15
        self.ma20 = ma20
        self.ma25 = ma25
        self.ma30 = ma30
        self.ma35 = ma35
        self.ma40 = ma40
        self.ma45 = ma45
        self.ma50 = ma50
        self.ma55 = ma55
        self.ma60 = ma60
        self.ma65 = ma65
        self.ma70 = ma70
        self.ma75 = ma75
        self.ma80 = ma80
        self.ma85 = ma85
        self.ma90 = ma90
        self.ma100 = ma100
        
        self.status = self.MMAR_main()
        self.msg = "Message goes here"
    
    def change_diff(self,ma):
        # Subtract previous from new
        sub_result = ma[0] - ma[-1]
        return sub_result
        
    def leadMAColor(self):
        # Get Lead line (ma05)'s color
        if self.change_diff(self.ma05) >= 0 and self.ma05[0] > self.ma100[0]:
            return "lime"

        elif self.change_diff(self.ma05) < 0 and self.ma05[0] > self.ma100[0]:
            return "maroon"
        
        elif self.change_diff(self.ma05) <= 0 and self.ma05[0] < self.ma100[0]:
            return "red"
        
        elif self.change_diff(self.ma05) >= 0 and self.ma05[0] < self.ma100[0]:
            return "green"
        
        else:
            return "gray"
        
    def maColor(self, ma, maRef):
        # Get a particular MA's color
        if self.change_diff(ma) >= 0 and self.ma05[0] > maRef[0]:
            return "lime"

        elif self.change_diff(ma) < 0 and self.ma05[0] > maRef[0]:
            return "maroon"
        
        elif self.change_diff(ma) <= 0 and self.ma05[0] < maRef[0]:
            return "red"
        
        elif self.change_diff(ma) >= 0 and self.ma05[0] < maRef[0]:
            return "green"
        
        else:
            return "gray"

        
    def MMAR_main(self):
        # BUY and SELL Stochastic Logic
        if self.leadMAColor() == 'lime' and self.maColor(self.ma10, self.ma100)  == 'lime' and self.maColor(self.ma15, self.ma100)  == 'lime' and self.maColor(self.ma20, self.ma100)  == 'lime' and self.maColor(self.ma25, self.ma100)  == 'lime' and self.maColor(self.ma30, self.ma100)  == 'lime' and self.maColor(self.ma35, self.ma100)  == 'lime' and self.maColor(self.ma40, self.ma100)  == 'lime' and self.maColor(self.ma45, self.ma100)  == 'lime' and self.maColor(self.ma50, self.ma100)  == 'lime' and self.maColor(self.ma55, self.ma100)  == 'lime' and self.maColor(self.ma60, self.ma100)  == 'lime' and self.maColor(self.ma65, self.ma100)  == 'lime' and self.maColor(self.ma70, self.ma100)  == 'lime' and self.maColor(self.ma75, self.ma100)  == 'lime' and self.maColor(self.ma80, self.ma100)  == 'lime' and self.maColor(self.ma85, self.ma100)  == 'lime' and self.maColor(self.ma90, self.ma100)  == 'lime':
            return "buy"

        elif self.leadMAColor() == 'red' and self.maColor(self.ma10, self.ma100)  == 'red' and self.maColor(self.ma15, self.ma100)  == 'red' and self.maColor(self.ma20, self.ma100)  == 'red' and self.maColor(self.ma25, self.ma100)  == 'red' and self.maColor(self.ma30, self.ma100)  == 'red' and self.maColor(self.ma35, self.ma100)  == 'red' and self.maColor(self.ma40, self.ma100)  == 'red' and self.maColor(self.ma45, self.ma100)  == 'red' and self.maColor(self.ma50, self.ma100)  == 'red' and self.maColor(self.ma55, self.ma100)  == 'red' and self.maColor(self.ma60, self.ma100)  == 'red' and self.maColor(self.ma65, self.ma100)  == 'red' and self.maColor(self.ma70, self.ma100)  == 'red' and self.maColor(self.ma75, self.ma100)  == 'red' and self.maColor(self.ma80, self.ma100)  == 'red' and self.maColor(self.ma85, self.ma100)  == 'red' and self.maColor(self.ma90, self.ma100)  == 'red':
            return "sell"
        
        elif self.leadMAColor() == 'green' and self.maColor(self.ma10, self.ma100)  == 'green' :
            return "close fall"
        
        elif self.leadMAColor() == 'maroon' and self.maColor(self.ma10, self.ma100)  == 'maroon' :
            return "close long"
        
        else:
            return "neutral"
        
        




class forexSpreadCommisionScheme(bt.CommInfoBase):
    '''
    This commission scheme attempts to calcuate the commission hidden in the
    spread by most forex brokers. It assumes a mid point data is being used.

    *New Params*
    spread: Float, the spread in pips of the instrument
    JPY_pair: Bool, states whether the pair being traded is a JPY pair
    acc_counter_currency: Bool, states whether the account currency is the same
    as the counter currency. If false, it is assumed to be the base currency
    '''
    params = (
        ('spread', 1),
        ('stocklike', False),
        ('JPY_pair', False),
        ('acc_counter_currency', True),
        ('commtype', bt.CommInfoBase.COMM_FIXED),
        )

    
    def _getcommission(self, size, price, pseudoexec):
        '''
        This scheme will apply half the commission when buying and half when selling.
        If JPY pair change the multiplier accordingly.
        If account currency is same as the base currency, change pip value calc.
        '''
        if self.p.JPY_pair == True:
            multiplier = 0.01
        else:
            multiplier = 0.0001

        if self.p.acc_counter_currency == True:
            comm = abs((self.p.spread * (size * multiplier)/2))

        else:
            comm =  abs((self.p.spread * ((size / price) * multiplier)/2))

        return comm
    
    
    
    
    
    
    
    
    
    
    
    
    
    
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = dict(
        stop_loss=0.02,  # price is 2% less than the entry point
        trail=True,
    )
    
    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
        
        
        
    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.datahigh = self.datas[0].high
        self.datalow = self.datas[0].low
        
         # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        self.setclose = None
        self.setposition = None
        self.broker_order = "close"
        
        
        # EMA indicators
        self.ma05 = bt.talib.EMA(timeperiod=5, plotname='TA_EMA_05')
        self.ma10 = bt.talib.EMA(timeperiod=10, plotname='TA_EMA_10')
        self.ma15 = bt.talib.EMA(timeperiod=15, plotname='TA_EMA_15')
        self.ma20 = bt.talib.EMA(timeperiod=20, plotname='TA_EMA_20')
        self.ma25 = bt.talib.EMA(timeperiod=25, plotname='TA_EMA_25')
        self.ma30 = bt.talib.EMA(timeperiod=30, plotname='TA_EMA_30')
        self.ma35 = bt.talib.EMA(timeperiod=35, plotname='TA_EMA_35')
        self.ma40 = bt.talib.EMA(timeperiod=40, plotname='TA_EMA_40')
        self.ma45 = bt.talib.EMA(timeperiod=45, plotname='TA_EMA_45')
        self.ma50 = bt.talib.EMA(timeperiod=50, plotname='TA_EMA_50')
        self.ma55 = bt.talib.EMA(timeperiod=55, plotname='TA_EMA_55')
        self.ma60 = bt.talib.EMA(timeperiod=60, plotname='TA_EMA_60')
        self.ma65 = bt.talib.EMA(timeperiod=65, plotname='TA_EMA_65')
        self.ma70 = bt.talib.EMA(timeperiod=70, plotname='TA_EMA_70')
        self.ma75 = bt.talib.EMA(timeperiod=75, plotname='TA_EMA_75')
        self.ma80 = bt.talib.EMA(timeperiod=80, plotname='TA_EMA_80')
        self.ma85 = bt.talib.EMA(timeperiod=85, plotname='TA_EMA_85')
        self.ma90 = bt.talib.EMA(timeperiod=90, plotname='TA_EMA_90')
        self.ma95 = bt.talib.EMA(timeperiod=95, plotname='TA_EMA_95')
        self.ma100 = bt.talib.EMA(timeperiod=100, plotname='TA_EMA_100')
        
        # MACD
        self.macd = bt.talib.MACD(self.data, plotname='TA_MACD')
        
        
        
        
        

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                        (order.executed.price,
                         order.executed.value,
                         order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
                
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                        (order.executed.price,
                         order.executed.value,
                         order.executed.comm))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
            self.broker_order = "close"

        # Write down: no pending order
        self.order = None

        
        
        
        
        
    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
        
        # Print out the final result
        print('Current Portfolio Value: %.2f' % cerebro.broker.getvalue())

        
        
        
        
        
    
    
    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.4f' % self.dataclose[0])
        

        # Initialise SetupClass
        setup = setUpTrigger(self.ma05,self.ma10,self.ma15,self.ma20,self.ma25,self.ma30,self.ma35,self.ma40,self.ma45,self.ma50,self.ma55,self.ma60,self.ma65,self.ma70,self.ma75,self.ma80,self.ma85,self.ma90,self.ma100)   
        trigger = setup.status
        
        # Money Management Class
        # risk = moneyManagement(self.setposition, self.datas[0])
        # print("setUpTrigger status " + trigger)
        
        
        # Exit command
        if trigger == 'close long' and self.broker_order == "buy":
            print("Custom Close long called")
            self.broker_order = "close"
            # self.broker.cancel(self.order)
            self.close()
        elif trigger == "close short" and self.broker_order == "sell":
            print("Custom Close short called")
            self.broker_order = "close"
            # self.broker.cancel(self.order)
            self.close()
        elif trigger == "neutral":
            print("Custom Close called")
            self.broker_order = "close"
            # self.broker.cancel(self.order)
            self.close()
        
        
        
        print("trigger " + trigger)
        print("broker " + self.broker_order)    
            
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return
        
        
        # BUY and SELL Logic
        if trigger == "buy" and self.broker_order == "close":
            self.broker_order = "buy"
            
            # BUY, BUY, BUY!!! (with all possible default parameters)
            self.log('BUY CREATE, %.2f' % self.dataclose[0])
#             self.broker.cancel(self.order)
            self.close()
        
            # Keep track of the created order to avoid a 2nd order
            self.order = self.buy()

#             if not self.p.trail:
#                 stop_price = self.data.close[0] * (1.0 - self.p.stop_loss)
#                 self.buy(exectype=bt.Order.Stop, price=stop_price)
#             else:
#                 self.buy(exectype=bt.Order.StopTrail,
#                           trailamount=self.p.trail)

        elif trigger == "sell" and self.broker_order == "close":
            self.broker_order = "sell"
            
            # SELL, SELL, SELL!!! (with all possible default parameters)
            self.log('SELL CREATE, %.2f' % self.dataclose[0])
#             self.broker.cancel(self.order)
            self.close()
                    
            # Keep track of the created order to avoid a 2nd order
            self.order = self.sell()

#             if not self.p.trail:
#                 stop_price = self.data.close[0] * (1.0 - self.p.stop_loss)
#                 self.sell(exectype=bt.Order.Stop, price=stop_price)
#             else:
#                 self.sell(exectype=bt.Order.StopTrail,
#                           trailamount=self.p.trail)

        
            
            

if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
    datapath = os.path.join(modpath, 'backtrader\datas\EURUSD1h_01-01_01-04_3.txt')

    
    data = btfeed.GenericCSVData(
              dataname=datapath,
              timeframe=bt.TimeFrame.Minutes,
              compression=60,
              fromdate = datetime.datetime(2019,1,1),
              todate=datetime.datetime(2019,3,1),                                  
              nullvalue=0.0,
              dtformat=('%Y%m%d %H:%M:%S'),
              tmformat=('%H:%M:%S'),
              datetime=0,
              time=-1,
              open=2,
              high=3,
              low=4,
              close=5,
              volume=6
            )



    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    
    # Variable for our starting cash
    startcash = 100
    
    # Set our desired cash start
    cerebro.broker.setcash(startcash)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=30)
    # cerebro.addsizer(bt.sizers.PercentSizer, percents=20)
    

    # Set the commission
    # Add the new commissions scheme
#     comminfo = forexSpreadCommisionScheme(spread=10, acc_counter_currency=True)
#     cerebro.broker.addcommissioninfo(comminfo)
#     cerebro.broker.setcommission(mult=100.0)
    cerebro.broker.setcommission(commission=0.001, mult=100.0) # We set broker comissions of 0.1%

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Plot the result
    cerebro.plot(style='candlestick')

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    portvalue = cerebro.broker.getvalue()
    pnl = portvalue - startcash

    print('Final Portfolio Value: ${}'.format(portvalue))
    print('P/L: ${}'.format(pnl))
# Out:
# Starting Portfolio Value: 100.00
# 2019-01-08, Close, 1.1448
# trigger close long
# broker close
# 2019-01-08, Close, 1.1450
# trigger close long
# broker close
# 2019-01-08, Close, 1.1439
# trigger close long
# broker close
# 2019-01-08, Close, 1.1439
# trigger close long
# broker close
# 2019-01-08, Close, 1.1444
# trigger close long
# broker close
# 2019-01-08, Close, 1.1446
# trigger close long
# broker close
# 2019-01-08, Close, 1.1444
# trigger close long
# broker close
# 2019-01-08, Close, 1.1449
# trigger neutral
# broker close
# 2019-01-08, Close, 1.1452
# trigger buy
# broker close
# 2019-01-08, BUY CREATE, 1.15
# 2019-01-08, BUY EXECUTED, Price: 1.15, Cost: 34.36, Comm 0.03
# 2019-01-08, Close, 1.1446
# Custom Close long called
# trigger close long
# broker close
# 2019-01-08, SELL EXECUTED, Price: 1.14, Cost: 34.36, Comm 0.03
# 2019-01-08, OPERATION PROFIT, GROSS -1.83, NET -1.90
# Current Portfolio Value: 98.10
# 2019-01-08, Close, 1.1465
# trigger buy
# broker close
# 2019-01-08, BUY CREATE, 1.15
# 2019-01-08, BUY EXECUTED, Price: 1.15, Cost: 34.40, Comm 0.03
# 2019-01-08, Close, 1.1449
# Custom Close long called
# trigger close long
# broker close
# 2019-01-08, SELL EXECUTED, Price: 1.14, Cost: 34.40, Comm 0.03
# 2019-01-08, OPERATION PROFIT, GROSS -4.77, NET -4.84
# Current Portfolio Value: 93.26
# 2019-01-08, Close, 1.1427
# trigger close long
# broker close
# 2019-01-08, Close, 1.1439
# trigger close long
# broker close
# 2019-01-08, Close, 1.1442
# trigger close long
# broker close
# 2019-01-08, Close, 1.1443
# trigger neutral
# broker close
# 2019-01-08, Close, 1.1454
# trigger buy
# broker close
# 2019-01-08, BUY CREATE, 1.15
# 2019-01-08, BUY EXECUTED, Price: 1.15, Cost: 34.36, Comm 0.03
# 2019-01-08, Close, 1.1441
# Custom Close long called
# trigger close long
# broker close
# 2019-01-08, SELL EXECUTED, Price: 1.14, Cost: 34.36, Comm 0.03
# 2019-01-08, OPERATION PROFIT, GROSS -3.99, NET -4.06
# Current Portfolio Value: 89.20
# 2019-01-08, Close, 1.1442
# trigger close long
# broker close
# 2019-01-08, Close, 1.1440
# trigger close long
# broker close
# 2019-01-08, Close, 1.1441
# trigger close long
# broker close
# 2019-01-08, Close, 1.1441
# trigger close long
# broker close
# 2019-01-08, Close, 1.1457
# trigger buy
# broker close
# 2019-01-08, BUY CREATE, 1.15
# 2019-01-09, BUY EXECUTED, Price: 1.15, Cost: 34.37, Comm 0.03
# 2019-01-09, Close, 1.1456
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1457
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1452
# trigger neutral
# broker buy
# 2019-01-09, Close, 1.1454
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1460
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1461
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1459
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1466
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1463
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1460
# trigger neutral
# broker buy
# 2019-01-09, Close, 1.1452
# Custom Close long called
# trigger close long
# broker close
# 2019-01-09, SELL EXECUTED, Price: 1.15, Cost: 34.37, Comm 0.03
# 2019-01-09, OPERATION PROFIT, GROSS -1.53, NET -1.60
# Current Portfolio Value: 87.61
# 2019-01-09, Close, 1.1456
# trigger close long
# broker close
# 2019-01-09, Close, 1.1450
# trigger close long
# broker close
# 2019-01-09, Close, 1.1462
# trigger buy
# broker close
# 2019-01-09, BUY CREATE, 1.15
# 2019-01-09, BUY EXECUTED, Price: 1.15, Cost: 34.39, Comm 0.03
# 2019-01-09, Close, 1.1524
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1510
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1524
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1533
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1536
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1543
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1554
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1542
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1548
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1554
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1555
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1554
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1555
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1569
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1558
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1560
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1552
# trigger neutral
# broker buy
# 2019-01-10, Close, 1.1541
# Custom Close long called
# trigger close long
# broker close
# 2019-01-10, SELL EXECUTED, Price: 1.15, Cost: 34.39, Comm 0.03
# 2019-01-10, OPERATION PROFIT, GROSS 23.64, NET 23.57
# Current Portfolio Value: 111.18
# 2019-01-10, Close, 1.1529
# trigger close long
# broker close
# 2019-01-10, Close, 1.1524
# trigger close long
# broker close
# 2019-01-10, Close, 1.1528
# trigger close long
# broker close
# 2019-01-10, Close, 1.1529
# trigger close long
# broker close
# 2019-01-10, Close, 1.1534
# trigger neutral
# broker close
# 2019-01-10, Close, 1.1520
# trigger close long
# broker close
# 2019-01-10, Close, 1.1526
# trigger close long
# broker close
# 2019-01-10, Close, 1.1522
# trigger close long
# broker close
# 2019-01-10, Close, 1.1516
# trigger close long
# broker close
# 2019-01-10, Close, 1.1506
# trigger close long
# broker close
# 2019-01-10, Close, 1.1498
# trigger close long
# broker close
# 2019-01-10, Close, 1.1500
# trigger close long
# broker close
# 2019-01-10, Close, 1.1498
# trigger close long
# broker close
# 2019-01-10, Close, 1.1499
# trigger close long
# broker close
# 2019-01-10, Close, 1.1497
# trigger close long
# broker close
# 2019-01-10, Close, 1.1508
# trigger neutral
# broker close
# 2019-01-11, Close, 1.1511
# trigger neutral
# broker close
# 2019-01-11, Close, 1.1518
# trigger buy
# broker close
# 2019-01-11, BUY CREATE, 1.15
# 2019-01-11, BUY EXECUTED, Price: 1.15, Cost: 34.55, Comm 0.03
# 2019-01-11, Close, 1.1522
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1525
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1529
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1525
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1523
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1526
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1529
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1520
# Custom Close long called
# trigger close long
# broker close
# 2019-01-11, SELL EXECUTED, Price: 1.15, Cost: 34.55, Comm 0.03
# 2019-01-11, OPERATION PROFIT, GROSS 0.60, NET 0.53
# Current Portfolio Value: 111.71
# 2019-01-11, Close, 1.1535
# trigger buy
# broker close
# 2019-01-11, BUY CREATE, 1.15
# 2019-01-11, BUY EXECUTED, Price: 1.15, Cost: 34.60, Comm 0.03
# 2019-01-11, Close, 1.1532
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1528
# trigger neutral
# broker buy
# 2019-01-11, Close, 1.1526
# trigger neutral
# broker buy
# 2019-01-11, Close, 1.1470
# Custom Close long called
# trigger close long
# broker close
# 2019-01-11, SELL EXECUTED, Price: 1.15, Cost: 34.60, Comm 0.03
# 2019-01-11, OPERATION PROFIT, GROSS -19.41, NET -19.48
# Current Portfolio Value: 92.23
# 2019-01-11, Close, 1.1477
# trigger close long
# broker close
# 2019-01-11, Close, 1.1478
# trigger close long
# broker close
# 2019-01-11, Close, 1.1482
# trigger sell
# broker close
# 2019-01-11, SELL CREATE, 1.15
# 2019-01-11, SELL EXECUTED, Price: 1.15, Cost: -34.45, Comm 0.03
# 2019-01-11, Close, 1.1471
# trigger sell
# broker sell
# 2019-01-11, Close, 1.1465
# trigger sell
# broker sell
# 2019-01-11, Close, 1.1463
# trigger sell
# broker sell
# 2019-01-11, Close, 1.1466
# trigger sell
# broker sell
# 2019-01-13, Close, 1.1464
# trigger sell
# broker sell
# 2019-01-13, Close, 1.1460
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1463
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1476
# trigger close fall
# broker sell
# 2019-01-14, Close, 1.1467
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1468
# trigger neutral
# broker sell
# 2019-01-14, Close, 1.1476
# trigger close fall
# broker sell
# 2019-01-14, Close, 1.1478
# trigger close fall
# broker sell
# 2019-01-14, Close, 1.1474
# trigger close fall
# broker sell
# 2019-01-14, Close, 1.1479
# trigger close fall
# broker sell
# 2019-01-14, Close, 1.1475
# trigger neutral
# broker sell
# 2019-01-14, Close, 1.1462
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1462
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1470
# trigger neutral
# broker sell
# 2019-01-14, Close, 1.1468
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1460
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1465
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1467
# trigger neutral
# broker sell
# 2019-01-14, Close, 1.1479
# trigger close fall
# broker sell
# 2019-01-14, Close, 1.1477
# trigger close fall
# broker sell
# 2019-01-14, Close, 1.1469
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1466
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1469
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1468
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1466
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1473
# trigger close fall
# broker sell
# 2019-01-15, Close, 1.1477
# trigger close fall
# broker sell
# 2019-01-15, Close, 1.1485
# trigger close fall
# broker sell
# 2019-01-15, Close, 1.1483
# trigger close fall
# broker sell
# 2019-01-15, Close, 1.1485
# trigger buy
# broker sell
# 2019-01-15, Close, 1.1480
# trigger neutral
# broker sell
# 2019-01-15, Close, 1.1483
# trigger buy
# broker sell
# 2019-01-15, Close, 1.1476
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1470
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1461
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1434
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1429
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1432
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1430
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1439
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1454
# trigger close fall
# broker sell
# 2019-01-15, Close, 1.1439
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1392
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1390
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1401
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1413
# trigger neutral
# broker sell
# 2019-01-15, Close, 1.1412
# trigger neutral
# broker sell
# 2019-01-15, Close, 1.1406
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1414
# trigger close fall
# broker sell
# 2019-01-16, Close, 1.1410
# trigger neutral
# broker sell
# 2019-01-16, Close, 1.1398
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1401
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1403
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1410
# trigger close fall
# broker sell
# 2019-01-16, Close, 1.1412
# trigger close fall
# broker sell
# 2019-01-16, Close, 1.1398
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1394
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1421
# trigger close fall
# broker sell
# 2019-01-16, Close, 1.1410
# trigger close fall
# broker sell
# 2019-01-16, Close, 1.1400
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1378
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1390
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1398
# trigger close fall
# broker sell
# 2019-01-16, Close, 1.1394
# trigger neutral
# broker sell
# 2019-01-16, Close, 1.1407
# trigger close fall
# broker sell
# 2019-01-16, Close, 1.1400
# trigger close fall
# broker sell
# 2019-01-16, Close, 1.1407
# trigger close fall
# broker sell
# 2019-01-16, Close, 1.1398
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1392
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1391
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1395
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1399
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1398
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1394
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1390
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1388
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1382
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1388
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1396
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1394
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1400
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1400
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1401
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1398
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1380
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1385
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1386
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1381
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1389
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1391
# trigger close fall
# broker sell
# 2019-01-17, Close, 1.1388
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1392
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1394
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1395
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1395
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1394
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1394
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1389
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1395
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1391
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1396
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1398
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1407
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1405
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1403
# trigger close fall
# broker sell
# 2019-01-18, Close, 1.1398
# trigger neutral
# broker sell
# 2019-01-18, Close, 1.1374
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1367
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1362
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1358
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1365
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1370
# trigger neutral
# broker sell
# 2019-01-18, Close, 1.1365
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1361
# trigger sell
# broker sell
# 2019-01-20, Close, 1.1365
# trigger sell
# broker sell
# 2019-01-20, Close, 1.1365
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1374
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1376
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1377
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1375
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1379
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1378
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1380
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1385
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1375
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1371
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1377
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1369
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1368
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1361
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1364
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1363
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1369
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1368
# trigger neutral
# broker sell
# 2019-01-21, Close, 1.1368
# trigger neutral
# broker sell
# 2019-01-21, Close, 1.1369
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1368
# trigger neutral
# broker sell
# 2019-01-21, Close, 1.1366
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1369
# trigger close fall
# broker sell
# 2019-01-21, Close, 1.1369
# trigger close fall
# broker sell
# 2019-01-22, Close, 1.1368
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1370
# trigger close fall
# broker sell
# 2019-01-22, Close, 1.1370
# trigger close fall
# broker sell
# 2019-01-22, Close, 1.1362
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1358
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1357
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1354
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1353
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1361
# trigger neutral
# broker sell
# 2019-01-22, Close, 1.1361
# trigger neutral
# broker sell
# 2019-01-22, Close, 1.1362
# trigger close fall
# broker sell
# 2019-01-22, Close, 1.1358
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1355
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1345
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1355
# trigger neutral
# broker sell
# 2019-01-22, Close, 1.1356
# trigger neutral
# broker sell
# 2019-01-22, Close, 1.1359
# trigger close fall
# broker sell
# 2019-01-22, Close, 1.1369
# trigger close fall
# broker sell
# 2019-01-22, Close, 1.1368
# trigger close fall
# broker sell
# 2019-01-22, Close, 1.1362
# trigger neutral
# broker sell
# 2019-01-22, Close, 1.1352
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1360
# trigger close fall
# broker sell
# 2019-01-22, Close, 1.1363
# trigger close fall
# broker sell
# 2019-01-22, Close, 1.1363
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1364
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1365
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1365
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1364
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1366
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1368
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1371
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1365
# trigger neutral
# broker sell
# 2019-01-23, Close, 1.1362
# trigger sell
# broker sell
# 2019-01-23, Close, 1.1356
# trigger sell
# broker sell
# 2019-01-23, Close, 1.1358
# trigger sell
# broker sell
# 2019-01-23, Close, 1.1365
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1366
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1354
# trigger sell
# broker sell
# 2019-01-23, Close, 1.1363
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1379
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1389
# trigger close fall
# broker sell
# 2019-01-23, Close, 1.1393
# trigger buy
# broker sell
# 2019-01-23, Close, 1.1387
# trigger buy
# broker sell
# 2019-01-23, Close, 1.1383
# trigger buy
# broker sell
# 2019-01-23, Close, 1.1382
# trigger neutral
# broker sell
# 2019-01-23, Close, 1.1381
# trigger neutral
# broker sell
# 2019-01-23, Close, 1.1380
# trigger neutral
# broker sell
# 2019-01-23, Close, 1.1386
# trigger buy
# broker sell
# 2019-01-24, Close, 1.1387
# trigger buy
# broker sell
# 2019-01-24, Close, 1.1387
# trigger buy
# broker sell
# 2019-01-24, Close, 1.1386
# trigger buy
# broker sell
# 2019-01-24, Close, 1.1388
# trigger buy
# broker sell
# 2019-01-24, Close, 1.1386
# trigger neutral
# broker sell
# 2019-01-24, Close, 1.1385
# trigger neutral
# broker sell
# 2019-01-24, Close, 1.1380
# trigger close long
# broker sell
# 2019-01-24, Close, 1.1370
# trigger close long
# broker sell
# 2019-01-24, Close, 1.1365
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1347
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1344
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1346
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1340
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1335
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1378
# trigger close fall
# broker sell
# 2019-01-24, Close, 1.1354
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1321
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1299
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1304
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1299
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1308
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1302
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1302
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1313
# trigger neutral
# broker sell
# 2019-01-25, Close, 1.1310
# trigger neutral
# broker sell
# 2019-01-25, Close, 1.1308
# trigger sell
# broker sell
# 2019-01-25, Close, 1.1320
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1321
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1320
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1322
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1324
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1324
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1327
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1330
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1338
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1346
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1342
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1357
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1379
# trigger close fall
# broker sell
# 2019-01-25, Close, 1.1397
# trigger buy
# broker sell
# 2019-01-25, Close, 1.1406
# trigger buy
# broker sell
# 2019-01-25, Close, 1.1405
# trigger buy
# broker sell
# 2019-01-25, Close, 1.1407
# trigger buy
# broker sell
# 2019-01-25, Close, 1.1414
# trigger buy
# broker sell
# 2019-01-25, Close, 1.1415
# trigger buy
# broker sell
# 2019-01-25, Close, 1.1403
# trigger neutral
# broker sell
# 2019-01-27, Close, 1.1409
# trigger buy
# broker sell
# 2019-01-27, Close, 1.1413
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1411
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1415
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1414
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1419
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1419
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1412
# trigger neutral
# broker sell
# 2019-01-28, Close, 1.1408
# trigger close long
# broker sell
# 2019-01-28, Close, 1.1406
# trigger close long
# broker sell
# 2019-01-28, Close, 1.1401
# trigger close long
# broker sell
# 2019-01-28, Close, 1.1408
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1414
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1407
# trigger close long
# broker sell
# 2019-01-28, Close, 1.1412
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1417
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1427
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1436
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1437
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1434
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1435
# trigger buy
# broker sell
# 2019-01-28, Close, 1.1428
# trigger neutral
# broker sell
# 2019-01-28, Close, 1.1428
# trigger neutral
# broker sell
# 2019-01-28, Close, 1.1427
# trigger neutral
# broker sell
# 2019-01-28, Close, 1.1427
# trigger neutral
# broker sell
# 2019-01-28, Close, 1.1429
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1426
# trigger close long
# broker sell
# 2019-01-29, Close, 1.1425
# trigger close long
# broker sell
# 2019-01-29, Close, 1.1430
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1429
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1432
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1433
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1435
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1435
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1441
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1441
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1440
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1436
# trigger neutral
# broker sell
# 2019-01-29, Close, 1.1425
# trigger close long
# broker sell
# 2019-01-29, Close, 1.1426
# trigger close long
# broker sell
# 2019-01-29, Close, 1.1425
# trigger close long
# broker sell
# 2019-01-29, Close, 1.1416
# trigger close long
# broker sell
# 2019-01-29, Close, 1.1424
# trigger close long
# broker sell
# 2019-01-29, Close, 1.1428
# trigger neutral
# broker sell
# 2019-01-29, Close, 1.1424
# trigger close long
# broker sell
# 2019-01-29, Close, 1.1428
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1433
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1431
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1434
# trigger buy
# broker sell
# 2019-01-29, Close, 1.1435
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1435
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1439
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1440
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1437
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1440
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1445
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1435
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1431
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1432
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1430
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1429
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1434
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1431
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1425
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1414
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1425
# trigger neutral
# broker sell
# 2019-01-30, Close, 1.1417
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1419
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1417
# trigger close long
# broker sell
# 2019-01-30, Close, 1.1492
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1481
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1479
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1481
# trigger buy
# broker sell
# 2019-01-30, Close, 1.1485
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1488
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1493
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1503
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1502
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1503
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1505
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1500
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1496
# trigger neutral
# broker sell
# 2019-01-31, Close, 1.1491
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1484
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1477
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1487
# trigger neutral
# broker sell
# 2019-01-31, Close, 1.1493
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1494
# trigger buy
# broker sell
# 2019-01-31, Close, 1.1477
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1475
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1453
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1450
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1444
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1444
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1445
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1447
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1446
# trigger close long
# broker sell
# 2019-01-31, Close, 1.1448
# trigger neutral
# broker sell
# 2019-02-01, Close, 1.1448
# trigger close long
# broker sell
# 2019-02-01, Close, 1.1442
# trigger close long
# broker sell
# 2019-02-01, Close, 1.1442
# trigger close long
# broker sell
# 2019-02-01, Close, 1.1442
# trigger close long
# broker sell
# 2019-02-01, Close, 1.1442
# trigger close long
# broker sell
# 2019-02-01, Close, 1.1437
# trigger close long
# broker sell
# 2019-02-01, Close, 1.1442
# trigger neutral
# broker sell
# 2019-02-01, Close, 1.1448
# trigger neutral
# broker sell
# 2019-02-01, Close, 1.1448
# trigger neutral
# broker sell
# 2019-02-01, Close, 1.1466
# trigger buy
# broker sell
# 2019-02-01, Close, 1.1467
# trigger buy
# broker sell
# 2019-02-01, Close, 1.1470
# trigger buy
# broker sell
# 2019-02-01, Close, 1.1469
# trigger buy
# broker sell
# 2019-02-01, Close, 1.1474
# trigger buy
# broker sell
# 2019-02-01, Close, 1.1476
# trigger buy
# broker sell
# 2019-02-01, Close, 1.1468
# trigger neutral
# broker sell
# 2019-02-01, Close, 1.1473
# trigger buy
# broker sell
# 2019-02-01, Close, 1.1468
# trigger neutral
# broker sell
# 2019-02-01, Close, 1.1460
# trigger close long
# broker sell
# 2019-02-01, Close, 1.1460
# trigger close long
# broker sell
# 2019-02-01, Close, 1.1459
# trigger close long
# broker sell
# 2019-02-01, Close, 1.1455
# trigger close long
# broker sell
# 2019-02-03, Close, 1.1456
# trigger close long
# broker sell
# 2019-02-03, Close, 1.1454
# trigger close long
# broker sell
# 2019-02-04, Close, 1.1456
# trigger close long
# broker sell
# 2019-02-04, Close, 1.1458
# trigger neutral
# broker sell
# 2019-02-04, Close, 1.1453
# trigger close long
# broker sell
# 2019-02-04, Close, 1.1448
# trigger close long
# broker sell
# 2019-02-04, Close, 1.1442
# trigger close long
# broker sell
# 2019-02-04, Close, 1.1443
# trigger close long
# broker sell
# 2019-02-04, Close, 1.1444
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1442
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1451
# trigger neutral
# broker sell
# 2019-02-04, Close, 1.1445
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1446
# trigger neutral
# broker sell
# 2019-02-04, Close, 1.1452
# trigger neutral
# broker sell
# 2019-02-04, Close, 1.1448
# trigger close long
# broker sell
# 2019-02-04, Close, 1.1449
# trigger neutral
# broker sell
# 2019-02-04, Close, 1.1426
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1429
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1438
# trigger neutral
# broker sell
# 2019-02-04, Close, 1.1431
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1432
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1431
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1434
# trigger neutral
# broker sell
# 2019-02-04, Close, 1.1435
# trigger neutral
# broker sell
# 2019-02-04, Close, 1.1435
# trigger neutral
# broker sell
# 2019-02-04, Close, 1.1435
# trigger neutral
# broker sell
# 2019-02-05, Close, 1.1436
# trigger neutral
# broker sell
# 2019-02-05, Close, 1.1438
# trigger close fall
# broker sell
# 2019-02-05, Close, 1.1439
# trigger close fall
# broker sell
# 2019-02-05, Close, 1.1433
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1432
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1434
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1433
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1425
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1414
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1419
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1417
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1421
# trigger neutral
# broker sell
# 2019-02-05, Close, 1.1421
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1429
# trigger close fall
# broker sell
# 2019-02-05, Close, 1.1414
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1406
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1405
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1409
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1413
# trigger neutral
# broker sell
# 2019-02-05, Close, 1.1409
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1413
# trigger neutral
# broker sell
# 2019-02-05, Close, 1.1405
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1404
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1409
# trigger neutral
# broker sell
# 2019-02-06, Close, 1.1406
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1401
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1403
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1398
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1401
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1397
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1390
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1389
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1391
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1388
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1397
# trigger close fall
# broker sell
# 2019-02-06, Close, 1.1385
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1392
# trigger neutral
# broker sell
# 2019-02-06, Close, 1.1387
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1383
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1377
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1380
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1375
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1366
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1364
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1368
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1362
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1367
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1366
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1364
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1361
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1361
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1360
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1362
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1360
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1366
# trigger close fall
# broker sell
# 2019-02-07, Close, 1.1354
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1355
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1345
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1336
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1328
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1344
# trigger neutral
# broker sell
# 2019-02-07, Close, 1.1331
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1347
# trigger close fall
# broker sell
# 2019-02-07, Close, 1.1356
# trigger close fall
# broker sell
# 2019-02-07, Close, 1.1356
# trigger close fall
# broker sell
# 2019-02-07, Close, 1.1349
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1354
# trigger close fall
# broker sell
# 2019-02-07, Close, 1.1349
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1342
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1339
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1342
# trigger sell
# broker sell
# 2019-02-07, Close, 1.1338
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1340
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1338
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1338
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1340
# trigger neutral
# broker sell
# 2019-02-08, Close, 1.1341
# trigger neutral
# broker sell
# 2019-02-08, Close, 1.1339
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1338
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1340
# trigger neutral
# broker sell
# 2019-02-08, Close, 1.1332
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1325
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1338
# trigger close fall
# broker sell
# 2019-02-08, Close, 1.1339
# trigger close fall
# broker sell
# 2019-02-08, Close, 1.1347
# trigger close fall
# broker sell
# 2019-02-08, Close, 1.1347
# trigger close fall
# broker sell
# 2019-02-08, Close, 1.1338
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1328
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1326
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1329
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1325
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1323
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1322
# trigger sell
# broker sell
# 2019-02-08, Close, 1.1321
# trigger sell
# broker sell
# 2019-02-10, Close, 1.1318
# trigger sell
# broker sell
# 2019-02-10, Close, 1.1324
# trigger neutral
# broker sell
# 2019-02-11, Close, 1.1323
# trigger neutral
# broker sell
# 2019-02-11, Close, 1.1327
# trigger close fall
# broker sell
# 2019-02-11, Close, 1.1324
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1320
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1319
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1324
# trigger close fall
# broker sell
# 2019-02-11, Close, 1.1327
# trigger close fall
# broker sell
# 2019-02-11, Close, 1.1321
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1311
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1302
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1304
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1314
# trigger neutral
# broker sell
# 2019-02-11, Close, 1.1312
# trigger neutral
# broker sell
# 2019-02-11, Close, 1.1310
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1292
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1276
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1276
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1270
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1271
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1276
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1276
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1275
# trigger sell
# broker sell
# 2019-02-11, Close, 1.1277
# trigger neutral
# broker sell
# 2019-02-11, Close, 1.1279
# trigger neutral
# broker sell
# 2019-02-12, Close, 1.1276
# trigger sell
# broker sell
# 2019-02-12, Close, 1.1282
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1283
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1280
# trigger neutral
# broker sell
# 2019-02-12, Close, 1.1276
# trigger sell
# broker sell
# 2019-02-12, Close, 1.1279
# trigger neutral
# broker sell
# 2019-02-12, Close, 1.1284
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1285
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1266
# trigger sell
# broker sell
# 2019-02-12, Close, 1.1274
# trigger sell
# broker sell
# 2019-02-12, Close, 1.1286
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1282
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1289
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1293
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1295
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1299
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1316
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1320
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1331
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1332
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1332
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1325
# trigger close fall
# broker sell
# 2019-02-12, Close, 1.1329
# trigger buy
# broker sell
# 2019-02-12, Close, 1.1334
# trigger buy
# broker sell
# 2019-02-13, Close, 1.1328
# trigger neutral
# broker sell
# 2019-02-13, Close, 1.1335
# trigger buy
# broker sell
# 2019-02-13, Close, 1.1336
# trigger buy
# broker sell
# 2019-02-13, Close, 1.1340
# trigger buy
# broker sell
# 2019-02-13, Close, 1.1337
# trigger buy
# broker sell
# 2019-02-13, Close, 1.1338
# trigger buy
# broker sell
# 2019-02-13, Close, 1.1332
# trigger neutral
# broker sell
# 2019-02-13, Close, 1.1320
# trigger close long
# broker sell
# 2019-02-13, Close, 1.1327
# trigger close long
# broker sell
# 2019-02-13, Close, 1.1321
# trigger neutral
# broker sell
# 2019-02-13, Close, 1.1317
# trigger neutral
# broker sell
# 2019-02-13, Close, 1.1330
# trigger close fall
# broker sell
# 2019-02-13, Close, 1.1306
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1291
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1298
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1286
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1288
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1276
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1279
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1270
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1266
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1260
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1257
# trigger sell
# broker sell
# 2019-02-13, Close, 1.1265
# trigger sell
# broker sell
# 2019-02-14, Close, 1.1264
# trigger sell
# broker sell
# 2019-02-14, Close, 1.1269
# trigger neutral
# broker sell
# 2019-02-14, Close, 1.1272
# trigger neutral
# broker sell
# 2019-02-14, Close, 1.1282
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1280
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1280
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1277
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1286
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1260
# trigger sell
# broker sell
# 2019-02-14, Close, 1.1266
# trigger sell
# broker sell
# 2019-02-14, Close, 1.1272
# trigger neutral
# broker sell
# 2019-02-14, Close, 1.1269
# trigger sell
# broker sell
# 2019-02-14, Close, 1.1266
# trigger sell
# broker sell
# 2019-02-14, Close, 1.1302
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1296
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1276
# trigger sell
# broker sell
# 2019-02-14, Close, 1.1284
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1297
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1300
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1301
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1292
# trigger neutral
# broker sell
# 2019-02-14, Close, 1.1295
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1294
# trigger close fall
# broker sell
# 2019-02-14, Close, 1.1295
# trigger close fall
# broker sell
# 2019-02-15, Close, 1.1293
# trigger neutral
# broker sell
# 2019-02-15, Close, 1.1287
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1288
# trigger neutral
# broker sell
# 2019-02-15, Close, 1.1286
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1287
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1285
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1289
# trigger close fall
# broker sell
# 2019-02-15, Close, 1.1279
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1276
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1283
# trigger neutral
# broker sell
# 2019-02-15, Close, 1.1274
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1273
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1263
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1253
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1269
# trigger neutral
# broker sell
# 2019-02-15, Close, 1.1263
# trigger sell
# broker sell
# 2019-02-15, Close, 1.1268
# trigger neutral
# broker sell
# 2019-02-15, Close, 1.1273
# trigger close fall
# broker sell
# 2019-02-15, Close, 1.1300
# trigger close fall
# broker sell
# 2019-02-15, Close, 1.1295
# trigger close fall
# broker sell
# 2019-02-15, Close, 1.1299
# trigger close fall
# broker sell
# 2019-02-15, Close, 1.1293
# trigger close fall
# broker sell
# 2019-02-17, Close, 1.1290
# trigger neutral
# broker sell
# 2019-02-17, Close, 1.1295
# trigger close fall
# broker sell
# 2019-02-18, Close, 1.1303
# trigger close fall
# broker sell
# 2019-02-18, Close, 1.1310
# trigger buy
# broker sell
# 2019-02-18, Close, 1.1318
# trigger buy
# broker sell
# 2019-02-18, Close, 1.1317
# trigger buy
# broker sell
# 2019-02-18, Close, 1.1312
# trigger buy
# broker sell
# 2019-02-18, Close, 1.1308
# trigger neutral
# broker sell
# 2019-02-18, Close, 1.1308
# trigger neutral
# broker sell
# 2019-02-18, Close, 1.1307
# trigger neutral
# broker sell
# 2019-02-18, Close, 1.1307
# trigger neutral
# broker sell
# 2019-02-18, Close, 1.1315
# trigger buy
# broker sell
# 2019-02-18, Close, 1.1328
# trigger buy
# broker sell
# 2019-02-18, Close, 1.1330
# trigger buy
# broker sell
# 2019-02-18, Close, 1.1331
# trigger buy
# broker sell
# 2019-02-18, Close, 1.1322
# trigger neutral
# broker sell
# 2019-02-18, Close, 1.1322
# trigger neutral
# broker sell
# 2019-02-18, Close, 1.1307
# trigger close long
# broker sell
# 2019-02-18, Close, 1.1306
# trigger close long
# broker sell
# 2019-02-18, Close, 1.1311
# trigger close long
# broker sell
# 2019-02-18, Close, 1.1311
# trigger close long
# broker sell
# 2019-02-18, Close, 1.1312
# trigger close long
# broker sell
# 2019-02-18, Close, 1.1314
# trigger buy
# broker sell
# 2019-02-18, Close, 1.1308
# trigger close long
# broker sell
# 2019-02-18, Close, 1.1310
# trigger close long
# broker sell
# 2019-02-18, Close, 1.1311
# trigger neutral
# broker sell
# 2019-02-19, Close, 1.1305
# trigger close long
# broker sell
# 2019-02-19, Close, 1.1304
# trigger close long
# broker sell
# 2019-02-19, Close, 1.1301
# trigger close long
# broker sell
# 2019-02-19, Close, 1.1295
# trigger sell
# broker sell
# 2019-02-19, Close, 1.1297
# trigger sell
# broker sell
# 2019-02-19, Close, 1.1299
# trigger sell
# broker sell
# 2019-02-19, Close, 1.1296
# trigger sell
# broker sell
# 2019-02-19, Close, 1.1299
# trigger neutral
# broker sell
# 2019-02-19, Close, 1.1322
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1303
# trigger close long
# broker sell
# 2019-02-19, Close, 1.1307
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1283
# trigger sell
# broker sell
# 2019-02-19, Close, 1.1287
# trigger sell
# broker sell
# 2019-02-19, Close, 1.1296
# trigger neutral
# broker sell
# 2019-02-19, Close, 1.1320
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1334
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1328
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1348
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1349
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1340
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1343
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1340
# trigger buy
# broker sell
# 2019-02-19, Close, 1.1339
# trigger neutral
# broker sell
# 2019-02-19, Close, 1.1340
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1350
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1354
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1350
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1345
# trigger neutral
# broker sell
# 2019-02-20, Close, 1.1344
# trigger neutral
# broker sell
# 2019-02-20, Close, 1.1338
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1334
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1344
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1345
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1347
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1342
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1336
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1340
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1337
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1338
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1349
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1368
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1366
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1363
# trigger buy
# broker sell
# 2019-02-20, Close, 1.1351
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1340
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1336
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1345
# trigger close long
# broker sell
# 2019-02-20, Close, 1.1346
# trigger neutral
# broker sell
# 2019-02-21, Close, 1.1343
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1334
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1338
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1348
# trigger buy
# broker sell
# 2019-02-21, Close, 1.1350
# trigger buy
# broker sell
# 2019-02-21, Close, 1.1336
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1330
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1335
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1356
# trigger buy
# broker sell
# 2019-02-21, Close, 1.1327
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1344
# trigger buy
# broker sell
# 2019-02-21, Close, 1.1350
# trigger buy
# broker sell
# 2019-02-21, Close, 1.1352
# trigger buy
# broker sell
# 2019-02-21, Close, 1.1362
# trigger buy
# broker sell
# 2019-02-21, Close, 1.1343
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1347
# trigger neutral
# broker sell
# 2019-02-21, Close, 1.1338
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1330
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1329
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1336
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1338
# trigger neutral
# broker sell
# 2019-02-21, Close, 1.1333
# trigger close long
# broker sell
# 2019-02-21, Close, 1.1336
# trigger neutral
# broker sell
# 2019-02-21, Close, 1.1340
# trigger neutral
# broker sell
# 2019-02-22, Close, 1.1339
# trigger neutral
# broker sell
# 2019-02-22, Close, 1.1337
# trigger close long
# broker sell
# 2019-02-22, Close, 1.1339
# trigger neutral
# broker sell
# 2019-02-22, Close, 1.1339
# trigger neutral
# broker sell
# 2019-02-22, Close, 1.1336
# trigger close long
# broker sell
# 2019-02-22, Close, 1.1338
# trigger neutral
# broker sell
# 2019-02-22, Close, 1.1343
# trigger buy
# broker sell
# 2019-02-22, Close, 1.1346
# trigger buy
# broker sell
# 2019-02-22, Close, 1.1348
# trigger buy
# broker sell
# 2019-02-22, Close, 1.1340
# trigger close long
# broker sell
# 2019-02-22, Close, 1.1341
# trigger neutral
# broker sell
# 2019-02-22, Close, 1.1338
# trigger close long
# broker sell
# 2019-02-22, Close, 1.1327
# trigger close long
# broker sell
# 2019-02-22, Close, 1.1336
# trigger close long
# broker sell
# 2019-02-22, Close, 1.1334
# trigger close long
# broker sell
# 2019-02-22, Close, 1.1340
# trigger buy
# broker sell
# 2019-02-22, Close, 1.1341
# trigger buy
# broker sell
# 2019-02-22, Close, 1.1345
# trigger buy
# broker sell
# 2019-02-22, Close, 1.1343
# trigger buy
# broker sell
# 2019-02-22, Close, 1.1337
# trigger close long
# broker sell
# 2019-02-22, Close, 1.1332
# trigger close long
# broker sell
# 2019-02-22, Close, 1.1332
# trigger close long
# broker sell
# 2019-02-24, Close, 1.1336
# trigger neutral
# broker sell
# 2019-02-24, Close, 1.1342
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1348
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1344
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1340
# trigger close long
# broker sell
# 2019-02-25, Close, 1.1344
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1340
# trigger close long
# broker sell
# 2019-02-25, Close, 1.1343
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1348
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1357
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1345
# trigger close long
# broker sell
# 2019-02-25, Close, 1.1349
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1364
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1365
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1357
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1355
# trigger neutral
# broker sell
# 2019-02-25, Close, 1.1352
# trigger close long
# broker sell
# 2019-02-25, Close, 1.1346
# trigger close long
# broker sell
# 2019-02-25, Close, 1.1345
# trigger close long
# broker sell
# 2019-02-25, Close, 1.1348
# trigger close long
# broker sell
# 2019-02-25, Close, 1.1355
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1364
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1361
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1357
# trigger neutral
# broker sell
# 2019-02-25, Close, 1.1360
# trigger buy
# broker sell
# 2019-02-25, Close, 1.1365
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1361
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1357
# trigger close long
# broker sell
# 2019-02-26, Close, 1.1363
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1362
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1358
# trigger close long
# broker sell
# 2019-02-26, Close, 1.1359
# trigger close long
# broker sell
# 2019-02-26, Close, 1.1350
# trigger close long
# broker sell
# 2019-02-26, Close, 1.1350
# trigger close long
# broker sell
# 2019-02-26, Close, 1.1355
# trigger neutral
# broker sell
# 2019-02-26, Close, 1.1367
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1364
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1364
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1364
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1372
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1361
# trigger close long
# broker sell
# 2019-02-26, Close, 1.1359
# trigger close long
# broker sell
# 2019-02-26, Close, 1.1373
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1380
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1380
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1396
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1392
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1389
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1393
# trigger buy
# broker sell
# 2019-02-26, Close, 1.1393
# trigger buy
# broker sell
# 2019-02-27, Close, 1.1391
# trigger buy
# broker sell
# 2019-02-27, Close, 1.1386
# trigger neutral
# broker sell
# 2019-02-27, Close, 1.1382
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1379
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1377
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1378
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1375
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1378
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1394
# trigger buy
# broker sell
# 2019-02-27, Close, 1.1395
# trigger buy
# broker sell
# 2019-02-27, Close, 1.1395
# trigger buy
# broker sell
# 2019-02-27, Close, 1.1397
# trigger buy
# broker sell
# 2019-02-27, Close, 1.1383
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1385
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1382
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1381
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1369
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1369
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1376
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1369
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1371
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1369
# trigger close long
# broker sell
# 2019-02-27, Close, 1.1372
# trigger neutral
# broker sell
# 2019-02-27, Close, 1.1380
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1375
# trigger neutral
# broker sell
# 2019-02-28, Close, 1.1377
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1378
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1378
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1377
# trigger neutral
# broker sell
# 2019-02-28, Close, 1.1376
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1372
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1382
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1382
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1391
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1401
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1417
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1410
# trigger buy
# broker sell
# 2019-02-28, Close, 1.1386
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1383
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1387
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1378
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1382
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1380
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1378
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1373
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1370
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1371
# trigger close long
# broker sell
# 2019-02-28, Close, 1.1373
# trigger close long
# broker sell
# 2019-03-01, Close, 1.1370
# trigger close long
# broker sell
# Final Portfolio Value: 92.53
# Final Portfolio Value: $92.53046860000023
# P/L: $-7.469531399999767
