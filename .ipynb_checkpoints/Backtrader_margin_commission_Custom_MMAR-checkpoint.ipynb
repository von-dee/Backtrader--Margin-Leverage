# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt
import backtrader.feeds as btfeed




class setUpTrigger():
    
    def __init__(self, ma05, ma10, ma15, ma20, ma25, ma30, ma35, ma40, ma45, ma50, ma55, ma60, ma65, ma70, ma75, ma80, ma85, ma90, ma100):
        self.ma05 = ma05
        self.ma10 = ma10
        self.ma15 = ma15
        self.ma20 = ma20
        self.ma25 = ma25
        self.ma30 = ma30
        self.ma35 = ma35
        self.ma40 = ma40
        self.ma45 = ma45
        self.ma50 = ma50
        self.ma55 = ma55
        self.ma60 = ma60
        self.ma65 = ma65
        self.ma70 = ma70
        self.ma75 = ma75
        self.ma80 = ma80
        self.ma85 = ma85
        self.ma90 = ma90
        self.ma100 = ma100
        
        self.status = self.MMAR_main()
        self.msg = "Message goes here"
    
    def change_diff(self,ma):
        # Subtract previous from new
        sub_result = ma[0] - ma[-1]
        return sub_result
        
    def leadMAColor(self):
        # Get Lead line (ma05)'s color
        if self.change_diff(self.ma05) >= 0 and self.ma05[0] > self.ma100[0]:
            return "lime"

        elif self.change_diff(self.ma05) < 0 and self.ma05[0] > self.ma100[0]:
            return "maroon"
        
        elif self.change_diff(self.ma05) <= 0 and self.ma05[0] < self.ma100[0]:
            return "red"
        
        elif self.change_diff(self.ma05) >= 0 and self.ma05[0] < self.ma100[0]:
            return "green"
        
        else:
            return "gray"
        
    def maColor(self, ma, maRef):
        # Get a particular MA's color
        if self.change_diff(ma) >= 0 and self.ma05[0] > maRef[0]:
            return "lime"

        elif self.change_diff(ma) < 0 and self.ma05[0] > maRef[0]:
            return "maroon"
        
        elif self.change_diff(ma) <= 0 and self.ma05[0] < maRef[0]:
            return "red"
        
        elif self.change_diff(ma) >= 0 and self.ma05[0] < maRef[0]:
            return "green"
        
        else:
            return "gray"

        
    def MMAR_main(self):
        # BUY and SELL Stochastic Logic
        if self.leadMAColor() == 'lime' and self.maColor(self.ma10, self.ma100)  == 'lime' and self.maColor(self.ma15, self.ma100)  == 'lime' and self.maColor(self.ma20, self.ma100)  == 'lime' and self.maColor(self.ma25, self.ma100)  == 'lime' and self.maColor(self.ma30, self.ma100)  == 'lime' and self.maColor(self.ma35, self.ma100)  == 'lime' and self.maColor(self.ma40, self.ma100)  == 'lime' and self.maColor(self.ma45, self.ma100)  == 'lime' and self.maColor(self.ma50, self.ma100)  == 'lime' and self.maColor(self.ma55, self.ma100)  == 'lime' and self.maColor(self.ma60, self.ma100)  == 'lime' and self.maColor(self.ma65, self.ma100)  == 'lime' and self.maColor(self.ma70, self.ma100)  == 'lime' and self.maColor(self.ma75, self.ma100)  == 'lime' and self.maColor(self.ma80, self.ma100)  == 'lime' and self.maColor(self.ma85, self.ma100)  == 'lime' and self.maColor(self.ma90, self.ma100)  == 'lime':
            return "buy"

        elif self.leadMAColor() == 'red' and self.maColor(self.ma10, self.ma100)  == 'red' and self.maColor(self.ma15, self.ma100)  == 'red' and self.maColor(self.ma20, self.ma100)  == 'red' and self.maColor(self.ma25, self.ma100)  == 'red' and self.maColor(self.ma30, self.ma100)  == 'red' and self.maColor(self.ma35, self.ma100)  == 'red' and self.maColor(self.ma40, self.ma100)  == 'red' and self.maColor(self.ma45, self.ma100)  == 'red' and self.maColor(self.ma50, self.ma100)  == 'red' and self.maColor(self.ma55, self.ma100)  == 'red' and self.maColor(self.ma60, self.ma100)  == 'red' and self.maColor(self.ma65, self.ma100)  == 'red' and self.maColor(self.ma70, self.ma100)  == 'red' and self.maColor(self.ma75, self.ma100)  == 'red' and self.maColor(self.ma80, self.ma100)  == 'red' and self.maColor(self.ma85, self.ma100)  == 'red' and self.maColor(self.ma90, self.ma100)  == 'red':
            return "sell"
        
        else:
            return "close"
        
        

        
        
        
class moneyManagement():
    
    def __init__(self, position , data):
        self.position = position
        self.dataclose = data.close
        self.datahigh = data.high
        self.datalow = data.low
        
    def exitcommand(self):
        
        # Exit command
        if self.position == "buy" and self.datalow[0] > self.dataclose[0]:
            print("Custom Close called")
            return True
        elif self.position == "sell"  and self.datahigh[0] < self.dataclose[0]:
            print("Custom Close called")
            return True
        else:
            return False
        
    def size_position(self, price, stop, risk, acc_value, method=0, exchange_rate=None, JPY_pair=False):

        if JPY_pair == True: #check if a YEN cross and change the multiplier
            multiplier = 0.01
        else:
            multiplier = 0.0001

        #Calc how much to risk
        acc_value = acc_value    
        cash_risk = acc_value * risk
        stop_pips_int = abs((price - stop) / multiplier)
        pip_value = cash_risk / stop_pips_int

        if method == 1:
            #pip_value = pip_value * price
            units = pip_value / multiplier
            return units

        elif method == 2:
            pip_value = pip_value * exchange_rate
            units = pip_value / multiplier
            return units

        else: # is method 0
            units = pip_value / multiplier
            return units
        
    
    



class forexSpreadCommisionScheme(bt.CommInfoBase):
    '''
    This commission scheme attempts to calcuate the commission hidden in the
    spread by most forex brokers. It assumes a mid point data is being used.

    *New Params*
    spread: Float, the spread in pips of the instrument
    JPY_pair: Bool, states whether the pair being traded is a JPY pair
    acc_counter_currency: Bool, states whether the account currency is the same
    as the counter currency. If false, it is assumed to be the base currency
    '''
    params = (
        ('spread', 2),
        ('stocklike', False),
        ('JPY_pair', False),
        ('acc_counter_currency', True),
        ('commtype', bt.CommInfoBase.COMM_FIXED),
        )

    
    def _getcommission(self, size, price, pseudoexec):
        '''
        This scheme will apply half the commission when buying and half when selling.
        If JPY pair change the multiplier accordingly.
        If account currency is same as the base currency, change pip value calc.
        '''
        if self.p.JPY_pair == True:
            multiplier = 0.01
        else:
            multiplier = 0.0001

        if self.p.acc_counter_currency == True:
            comm = abs((self.p.spread * (size * multiplier)/2))

        else:
            comm =  abs((self.p.spread * ((size / price) * multiplier)/2))

        return comm
    
    
    
    
    
    
    
    
    
    
    
    
    
    
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = dict(
        stop_loss=0.02,  # price is 2% less than the entry point
        trail=False,
    )
    
    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
        
        
        
    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.datahigh = self.datas[0].high
        self.datalow = self.datas[0].low
        
         # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        self.setclose = None
        self.setposition = None
        self.broker_order = "close"
        
        
        # EMA indicators
        self.ma05 = bt.talib.EMA(timeperiod=5, plotname='TA_EMA_05')
        self.ma10 = bt.talib.EMA(timeperiod=10, plotname='TA_EMA_10')
        self.ma15 = bt.talib.EMA(timeperiod=15, plotname='TA_EMA_15')
        self.ma20 = bt.talib.EMA(timeperiod=20, plotname='TA_EMA_20')
        self.ma25 = bt.talib.EMA(timeperiod=25, plotname='TA_EMA_25')
        self.ma30 = bt.talib.EMA(timeperiod=30, plotname='TA_EMA_30')
        self.ma35 = bt.talib.EMA(timeperiod=35, plotname='TA_EMA_35')
        self.ma40 = bt.talib.EMA(timeperiod=40, plotname='TA_EMA_40')
        self.ma45 = bt.talib.EMA(timeperiod=45, plotname='TA_EMA_45')
        self.ma50 = bt.talib.EMA(timeperiod=50, plotname='TA_EMA_50')
        self.ma55 = bt.talib.EMA(timeperiod=55, plotname='TA_EMA_55')
        self.ma60 = bt.talib.EMA(timeperiod=60, plotname='TA_EMA_60')
        self.ma65 = bt.talib.EMA(timeperiod=65, plotname='TA_EMA_65')
        self.ma70 = bt.talib.EMA(timeperiod=70, plotname='TA_EMA_70')
        self.ma75 = bt.talib.EMA(timeperiod=75, plotname='TA_EMA_75')
        self.ma80 = bt.talib.EMA(timeperiod=80, plotname='TA_EMA_80')
        self.ma85 = bt.talib.EMA(timeperiod=85, plotname='TA_EMA_85')
        self.ma90 = bt.talib.EMA(timeperiod=90, plotname='TA_EMA_90')
        self.ma95 = bt.talib.EMA(timeperiod=95, plotname='TA_EMA_95')
        self.ma100 = bt.talib.EMA(timeperiod=100, plotname='TA_EMA_100')
        
        
        
        
        

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                        (order.executed.price,
                         order.executed.value,
                         order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
                
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                        (order.executed.price,
                         order.executed.value,
                         order.executed.comm))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
            self.broker_order = "close"

        # Write down: no pending order
        self.order = None

        
        
        
        
        
    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
        
        # Print out the final result
        print('Current Portfolio Value: %.2f' % cerebro.broker.getvalue())

        
        
        
        
        
    
    
    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.4f' % self.dataclose[0])
        

        # Initialise SetupClass
        setup = setUpTrigger(self.ma05,self.ma10,self.ma15,self.ma20,self.ma25,self.ma30,self.ma35,self.ma40,self.ma45,self.ma50,self.ma55,self.ma60,self.ma65,self.ma70,self.ma75,self.ma80,self.ma85,self.ma90,self.ma100)   
        trigger = setup.status
        
        # Money Management Class
        # risk = moneyManagement(self.setposition, self.datas[0])
        # print("setUpTrigger status " + trigger)
        
        
        # Exit command
        if trigger == 'close':
            print("Custom Close called")
            self.broker_order = "close"
            # self.broker.cancel(self.order)
            self.close()
        
        print("trigger " + trigger)
        print("broker " + self.broker_order)    
            
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return
        
        
        # BUY and SELL Logic
        if trigger == "buy" and self.broker_order == "close":
            self.broker_order = "buy"
            
            # BUY, BUY, BUY!!! (with all possible default parameters)
            self.log('BUY CREATE, %.2f' % self.dataclose[0])
#             self.broker.cancel(self.order)
            self.close()
        
            # Keep track of the created order to avoid a 2nd order
            self.order = self.buy()

        elif trigger == "sell" and self.broker_order == "close":
            self.broker_order = "sell"
            
            # SELL, SELL, SELL!!! (with all possible default parameters)
            self.log('SELL CREATE, %.2f' % self.dataclose[0])
#             self.broker.cancel(self.order)
            self.close()
                    
            # Keep track of the created order to avoid a 2nd order
            self.order = self.sell()

        
            
            

if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
    datapath = os.path.join(modpath, 'backtrader\datas\EURUSD1h_01-01_01-04_3.txt')

    
    data = btfeed.GenericCSVData(
              dataname=datapath,
              timeframe=bt.TimeFrame.Minutes,
              compression=60,
              fromdate = datetime.datetime(2019,1,1),
              todate=datetime.datetime(2019,4,1),                                  
              nullvalue=0.0,
              dtformat=('%Y%m%d %H:%M:%S'),
              tmformat=('%H:%M:%S'),
              datetime=0,
              time=-1,
              open=2,
              high=3,
              low=4,
              close=5,
              volume=6
            )



    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    
    # Variable for our starting cash
    startcash = 100
    
    # Set our desired cash start
    cerebro.broker.setcash(startcash)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=30)
    # cerebro.addsizer(bt.sizers.PercentSizer, percents=20)
    

    # Set the commission
    # Add the new commissions scheme
    comminfo = forexSpreadCommisionScheme(spread=10, acc_counter_currency=True)
    cerebro.broker.addcommissioninfo(comminfo)
    cerebro.broker.setcommission(mult=100.0)
#     cerebro.broker.setcommission(commission=0.001) # We set broker comissions of 0.1%

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Plot the result
    cerebro.plot(style='candlestick')

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    portvalue = cerebro.broker.getvalue()
    pnl = portvalue - startcash

    print('Final Portfolio Value: ${}'.format(portvalue))
    print('P/L: ${}'.format(pnl))
# Out:
# Starting Portfolio Value: 100000.00
# 2019-01-08, Close, 1.1448
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1450
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1439
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1439
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1444
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1446
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1444
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1449
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1452
# trigger buy
# broker close
# 2019-01-08, BUY CREATE, 1.15
# 2019-01-08, BUY EXECUTED, Price: 1.15, Cost: 34.36, Comm 0.00
# 2019-01-08, Close, 1.1446
# Custom Close called
# trigger close
# broker close
# 2019-01-08, SELL EXECUTED, Price: 1.14, Cost: 34.36, Comm 0.00
# 2019-01-08, OPERATION PROFIT, GROSS -1.83, NET -1.83
# Current Portfolio Value: 99998.17
# 2019-01-08, Close, 1.1465
# trigger buy
# broker close
# 2019-01-08, BUY CREATE, 1.15
# 2019-01-08, BUY EXECUTED, Price: 1.15, Cost: 34.40, Comm 0.00
# 2019-01-08, Close, 1.1449
# Custom Close called
# trigger close
# broker close
# 2019-01-08, SELL EXECUTED, Price: 1.14, Cost: 34.40, Comm 0.00
# 2019-01-08, OPERATION PROFIT, GROSS -4.77, NET -4.77
# Current Portfolio Value: 99993.40
# 2019-01-08, Close, 1.1427
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1439
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1442
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1443
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1454
# trigger buy
# broker close
# 2019-01-08, BUY CREATE, 1.15
# 2019-01-08, BUY EXECUTED, Price: 1.15, Cost: 34.36, Comm 0.00
# 2019-01-08, Close, 1.1441
# Custom Close called
# trigger close
# broker close
# 2019-01-08, SELL EXECUTED, Price: 1.14, Cost: 34.36, Comm 0.00
# 2019-01-08, OPERATION PROFIT, GROSS -3.99, NET -3.99
# Current Portfolio Value: 99989.41
# 2019-01-08, Close, 1.1442
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1440
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1441
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1441
# Custom Close called
# trigger close
# broker close
# 2019-01-08, Close, 1.1457
# trigger buy
# broker close
# 2019-01-08, BUY CREATE, 1.15
# 2019-01-09, BUY EXECUTED, Price: 1.15, Cost: 34.37, Comm 0.00
# 2019-01-09, Close, 1.1456
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1457
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1452
# Custom Close called
# trigger close
# broker close
# 2019-01-09, SELL EXECUTED, Price: 1.15, Cost: 34.37, Comm 0.00
# 2019-01-09, OPERATION PROFIT, GROSS -1.71, NET -1.71
# Current Portfolio Value: 99987.70
# 2019-01-09, Close, 1.1454
# trigger buy
# broker close
# 2019-01-09, BUY CREATE, 1.15
# 2019-01-09, BUY EXECUTED, Price: 1.15, Cost: 34.36, Comm 0.00
# 2019-01-09, Close, 1.1460
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1461
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1459
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1466
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1463
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1460
# Custom Close called
# trigger close
# broker close
# 2019-01-09, SELL EXECUTED, Price: 1.15, Cost: 34.36, Comm 0.00
# 2019-01-09, OPERATION PROFIT, GROSS 1.92, NET 1.92
# Current Portfolio Value: 99989.62
# 2019-01-09, Close, 1.1452
# Custom Close called
# trigger close
# broker close
# 2019-01-09, Close, 1.1456
# Custom Close called
# trigger close
# broker close
# 2019-01-09, Close, 1.1450
# Custom Close called
# trigger close
# broker close
# 2019-01-09, Close, 1.1462
# trigger buy
# broker close
# 2019-01-09, BUY CREATE, 1.15
# 2019-01-09, BUY EXECUTED, Price: 1.15, Cost: 34.39, Comm 0.00
# 2019-01-09, Close, 1.1524
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1510
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1524
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1533
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1536
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1543
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1554
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1542
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1548
# trigger buy
# broker buy
# 2019-01-09, Close, 1.1554
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1555
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1554
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1555
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1569
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1558
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1560
# trigger buy
# broker buy
# 2019-01-10, Close, 1.1552
# Custom Close called
# trigger close
# broker close
# 2019-01-10, SELL EXECUTED, Price: 1.16, Cost: 34.39, Comm 0.00
# 2019-01-10, OPERATION PROFIT, GROSS 26.94, NET 26.94
# Current Portfolio Value: 100016.56
# 2019-01-10, Close, 1.1541
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1529
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1524
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1528
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1529
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1534
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1520
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1526
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1522
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1516
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1506
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1498
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1500
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1498
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1499
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1497
# Custom Close called
# trigger close
# broker close
# 2019-01-10, Close, 1.1508
# Custom Close called
# trigger close
# broker close
# 2019-01-11, Close, 1.1511
# Custom Close called
# trigger close
# broker close
# 2019-01-11, Close, 1.1518
# trigger buy
# broker close
# 2019-01-11, BUY CREATE, 1.15
# 2019-01-11, BUY EXECUTED, Price: 1.15, Cost: 34.55, Comm 0.00
# 2019-01-11, Close, 1.1522
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1525
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1529
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1525
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1523
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1526
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1529
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1520
# Custom Close called
# trigger close
# broker close
# 2019-01-11, SELL EXECUTED, Price: 1.15, Cost: 34.55, Comm 0.00
# 2019-01-11, OPERATION PROFIT, GROSS 0.60, NET 0.60
# Current Portfolio Value: 100017.16
# 2019-01-11, Close, 1.1535
# trigger buy
# broker close
# 2019-01-11, BUY CREATE, 1.15
# 2019-01-11, BUY EXECUTED, Price: 1.15, Cost: 34.60, Comm 0.00
# 2019-01-11, Close, 1.1532
# trigger buy
# broker buy
# 2019-01-11, Close, 1.1528
# Custom Close called
# trigger close
# broker close
# 2019-01-11, SELL EXECUTED, Price: 1.15, Cost: 34.60, Comm 0.00
# 2019-01-11, OPERATION PROFIT, GROSS -1.98, NET -1.98
# Current Portfolio Value: 100015.18
# 2019-01-11, Close, 1.1526
# Custom Close called
# trigger close
# broker close
# 2019-01-11, Close, 1.1470
# Custom Close called
# trigger close
# broker close
# 2019-01-11, Close, 1.1477
# Custom Close called
# trigger close
# broker close
# 2019-01-11, Close, 1.1478
# Custom Close called
# trigger close
# broker close
# 2019-01-11, Close, 1.1482
# trigger sell
# broker close
# 2019-01-11, SELL CREATE, 1.15
# 2019-01-11, SELL EXECUTED, Price: 1.15, Cost: -34.45, Comm 0.00
# 2019-01-11, Close, 1.1471
# trigger sell
# broker sell
# 2019-01-11, Close, 1.1465
# trigger sell
# broker sell
# 2019-01-11, Close, 1.1463
# trigger sell
# broker sell
# 2019-01-11, Close, 1.1466
# trigger sell
# broker sell
# 2019-01-13, Close, 1.1464
# trigger sell
# broker sell
# 2019-01-13, Close, 1.1460
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1463
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1476
# Custom Close called
# trigger close
# broker close
# 2019-01-14, BUY EXECUTED, Price: 1.15, Cost: -34.45, Comm 0.00
# 2019-01-14, OPERATION PROFIT, GROSS 1.95, NET 1.95
# Current Portfolio Value: 100017.13
# 2019-01-14, Close, 1.1467
# trigger sell
# broker close
# 2019-01-14, SELL CREATE, 1.15
# 2019-01-14, SELL EXECUTED, Price: 1.15, Cost: -34.40, Comm 0.00
# 2019-01-14, Close, 1.1468
# Custom Close called
# trigger close
# broker close
# 2019-01-14, BUY EXECUTED, Price: 1.15, Cost: -34.40, Comm 0.00
# 2019-01-14, OPERATION PROFIT, GROSS -0.57, NET -0.57
# Current Portfolio Value: 100016.56
# 2019-01-14, Close, 1.1476
# Custom Close called
# trigger close
# broker close
# 2019-01-14, Close, 1.1478
# Custom Close called
# trigger close
# broker close
# 2019-01-14, Close, 1.1474
# Custom Close called
# trigger close
# broker close
# 2019-01-14, Close, 1.1479
# Custom Close called
# trigger close
# broker close
# 2019-01-14, Close, 1.1475
# Custom Close called
# trigger close
# broker close
# 2019-01-14, Close, 1.1462
# trigger sell
# broker close
# 2019-01-14, SELL CREATE, 1.15
# 2019-01-14, SELL EXECUTED, Price: 1.15, Cost: -34.39, Comm 0.00
# 2019-01-14, Close, 1.1462
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1470
# Custom Close called
# trigger close
# broker close
# 2019-01-14, BUY EXECUTED, Price: 1.15, Cost: -34.39, Comm 0.00
# 2019-01-14, OPERATION PROFIT, GROSS -2.34, NET -2.34
# Current Portfolio Value: 100014.22
# 2019-01-14, Close, 1.1468
# trigger sell
# broker close
# 2019-01-14, SELL CREATE, 1.15
# 2019-01-14, SELL EXECUTED, Price: 1.15, Cost: -34.40, Comm 0.00
# 2019-01-14, Close, 1.1460
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1465
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1467
# Custom Close called
# trigger close
# broker close
# 2019-01-14, BUY EXECUTED, Price: 1.15, Cost: -34.40, Comm 0.00
# 2019-01-14, OPERATION PROFIT, GROSS 0.18, NET 0.18
# Current Portfolio Value: 100014.40
# 2019-01-14, Close, 1.1479
# Custom Close called
# trigger close
# broker close
# 2019-01-14, Close, 1.1477
# Custom Close called
# trigger close
# broker close
# 2019-01-14, Close, 1.1469
# trigger sell
# broker close
# 2019-01-14, SELL CREATE, 1.15
# 2019-01-14, SELL EXECUTED, Price: 1.15, Cost: -34.41, Comm 0.00
# 2019-01-14, Close, 1.1466
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1469
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1468
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1466
# trigger sell
# broker sell
# 2019-01-14, Close, 1.1473
# Custom Close called
# trigger close
# broker close
# 2019-01-15, BUY EXECUTED, Price: 1.15, Cost: -34.41, Comm 0.00
# 2019-01-15, OPERATION PROFIT, GROSS -0.90, NET -0.90
# Current Portfolio Value: 100013.50
# 2019-01-15, Close, 1.1477
# Custom Close called
# trigger close
# broker close
# 2019-01-15, Close, 1.1485
# Custom Close called
# trigger close
# broker close
# 2019-01-15, Close, 1.1483
# Custom Close called
# trigger close
# broker close
# 2019-01-15, Close, 1.1485
# trigger buy
# broker close
# 2019-01-15, BUY CREATE, 1.15
# 2019-01-15, BUY EXECUTED, Price: 1.15, Cost: 34.46, Comm 0.00
# 2019-01-15, Close, 1.1480
# Custom Close called
# trigger close
# broker close
# 2019-01-15, SELL EXECUTED, Price: 1.15, Cost: 34.46, Comm 0.00
# 2019-01-15, OPERATION PROFIT, GROSS -1.62, NET -1.62
# Current Portfolio Value: 100011.88
# 2019-01-15, Close, 1.1483
# trigger buy
# broker close
# 2019-01-15, BUY CREATE, 1.15
# 2019-01-15, BUY EXECUTED, Price: 1.15, Cost: 34.45, Comm 0.00
# 2019-01-15, Close, 1.1476
# trigger sell
# broker buy
# 2019-01-15, Close, 1.1470
# trigger sell
# broker buy
# 2019-01-15, Close, 1.1461
# trigger sell
# broker buy
# 2019-01-15, Close, 1.1434
# trigger sell
# broker buy
# 2019-01-15, Close, 1.1429
# trigger sell
# broker buy
# 2019-01-15, Close, 1.1432
# trigger sell
# broker buy
# 2019-01-15, Close, 1.1430
# trigger sell
# broker buy
# 2019-01-15, Close, 1.1439
# trigger sell
# broker buy
# 2019-01-15, Close, 1.1454
# Custom Close called
# trigger close
# broker close
# 2019-01-15, SELL EXECUTED, Price: 1.15, Cost: 34.45, Comm 0.00
# 2019-01-15, OPERATION PROFIT, GROSS -8.73, NET -8.73
# Current Portfolio Value: 100003.15
# 2019-01-15, Close, 1.1439
# trigger sell
# broker close
# 2019-01-15, SELL CREATE, 1.14
# 2019-01-15, SELL EXECUTED, Price: 1.14, Cost: -34.32, Comm 0.00
# 2019-01-15, Close, 1.1392
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1390
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1401
# trigger sell
# broker sell
# 2019-01-15, Close, 1.1413
# Custom Close called
# trigger close
# broker close
# 2019-01-15, BUY EXECUTED, Price: 1.14, Cost: -34.32, Comm 0.00
# 2019-01-15, OPERATION PROFIT, GROSS 7.62, NET 7.62
# Current Portfolio Value: 100010.77
# 2019-01-15, Close, 1.1412
# Custom Close called
# trigger close
# broker close
# 2019-01-15, Close, 1.1406
# trigger sell
# broker close
# 2019-01-15, SELL CREATE, 1.14
# 2019-01-15, SELL EXECUTED, Price: 1.14, Cost: -34.22, Comm 0.00
# 2019-01-15, Close, 1.1414
# Custom Close called
# trigger close
# broker close
# 2019-01-16, BUY EXECUTED, Price: 1.14, Cost: -34.22, Comm 0.00
# 2019-01-16, OPERATION PROFIT, GROSS -2.49, NET -2.49
# Current Portfolio Value: 100008.28
# 2019-01-16, Close, 1.1410
# Custom Close called
# trigger close
# broker close
# 2019-01-16, Close, 1.1398
# trigger sell
# broker close
# 2019-01-16, SELL CREATE, 1.14
# 2019-01-16, SELL EXECUTED, Price: 1.14, Cost: -34.19, Comm 0.00
# 2019-01-16, Close, 1.1401
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1403
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1410
# Custom Close called
# trigger close
# broker close
# 2019-01-16, BUY EXECUTED, Price: 1.14, Cost: -34.19, Comm 0.00
# 2019-01-16, OPERATION PROFIT, GROSS -3.60, NET -3.60
# Current Portfolio Value: 100004.68
# 2019-01-16, Close, 1.1412
# Custom Close called
# trigger close
# broker close
# 2019-01-16, Close, 1.1398
# trigger sell
# broker close
# 2019-01-16, SELL CREATE, 1.14
# 2019-01-16, SELL EXECUTED, Price: 1.14, Cost: -34.19, Comm 0.00
# 2019-01-16, Close, 1.1394
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1421
# Custom Close called
# trigger close
# broker close
# 2019-01-16, BUY EXECUTED, Price: 1.14, Cost: -34.19, Comm 0.00
# 2019-01-16, OPERATION PROFIT, GROSS -7.05, NET -7.05
# Current Portfolio Value: 99997.63
# 2019-01-16, Close, 1.1410
# Custom Close called
# trigger close
# broker close
# 2019-01-16, Close, 1.1400
# trigger sell
# broker close
# 2019-01-16, SELL CREATE, 1.14
# 2019-01-16, SELL EXECUTED, Price: 1.14, Cost: -34.20, Comm 0.00
# 2019-01-16, Close, 1.1378
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1390
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1398
# Custom Close called
# trigger close
# broker close
# 2019-01-16, BUY EXECUTED, Price: 1.14, Cost: -34.20, Comm 0.00
# 2019-01-16, OPERATION PROFIT, GROSS 0.72, NET 0.72
# Current Portfolio Value: 99998.35
# 2019-01-16, Close, 1.1394
# Custom Close called
# trigger close
# broker close
# 2019-01-16, Close, 1.1407
# Custom Close called
# trigger close
# broker close
# 2019-01-16, Close, 1.1400
# Custom Close called
# trigger close
# broker close
# 2019-01-16, Close, 1.1407
# Custom Close called
# trigger close
# broker close
# 2019-01-16, Close, 1.1398
# trigger sell
# broker close
# 2019-01-16, SELL CREATE, 1.14
# 2019-01-16, SELL EXECUTED, Price: 1.14, Cost: -34.19, Comm 0.00
# 2019-01-16, Close, 1.1392
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1391
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1395
# trigger sell
# broker sell
# 2019-01-16, Close, 1.1399
# Custom Close called
# trigger close
# broker close
# 2019-01-17, BUY EXECUTED, Price: 1.14, Cost: -34.19, Comm 0.00
# 2019-01-17, OPERATION PROFIT, GROSS -0.54, NET -0.54
# Current Portfolio Value: 99997.81
# 2019-01-17, Close, 1.1398
# Custom Close called
# trigger close
# broker close
# 2019-01-17, Close, 1.1394
# trigger sell
# broker close
# 2019-01-17, SELL CREATE, 1.14
# 2019-01-17, SELL EXECUTED, Price: 1.14, Cost: -34.18, Comm 0.00
# 2019-01-17, Close, 1.1390
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1388
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1382
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1388
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1396
# Custom Close called
# trigger close
# broker close
# 2019-01-17, BUY EXECUTED, Price: 1.14, Cost: -34.18, Comm 0.00
# 2019-01-17, OPERATION PROFIT, GROSS -0.42, NET -0.42
# Current Portfolio Value: 99997.39
# 2019-01-17, Close, 1.1394
# Custom Close called
# trigger close
# broker close
# 2019-01-17, Close, 1.1400
# Custom Close called
# trigger close
# broker close
# 2019-01-17, Close, 1.1400
# Custom Close called
# trigger close
# broker close
# 2019-01-17, Close, 1.1401
# Custom Close called
# trigger close
# broker close
# 2019-01-17, Close, 1.1398
# Custom Close called
# trigger close
# broker close
# 2019-01-17, Close, 1.1387
# trigger sell
# broker close
# 2019-01-17, SELL CREATE, 1.14
# 2019-01-17, SELL EXECUTED, Price: 1.14, Cost: -34.16, Comm 0.00
# 2019-01-17, Close, 1.1380
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1385
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1386
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1381
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1389
# Custom Close called
# trigger close
# broker close
# 2019-01-17, BUY EXECUTED, Price: 1.14, Cost: -34.16, Comm 0.00
# 2019-01-17, OPERATION PROFIT, GROSS -0.75, NET -0.75
# Current Portfolio Value: 99996.64
# 2019-01-17, Close, 1.1391
# Custom Close called
# trigger close
# broker close
# 2019-01-17, Close, 1.1388
# trigger sell
# broker close
# 2019-01-17, SELL CREATE, 1.14
# 2019-01-17, SELL EXECUTED, Price: 1.14, Cost: -34.16, Comm 0.00
# 2019-01-17, Close, 1.1387
# trigger sell
# broker sell
# 2019-01-17, Close, 1.1392
# Custom Close called
# trigger close
# broker close
# 2019-01-18, BUY EXECUTED, Price: 1.14, Cost: -34.16, Comm 0.00
# 2019-01-18, OPERATION PROFIT, GROSS -1.20, NET -1.20
# Current Portfolio Value: 99995.44
# 2019-01-18, Close, 1.1394
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1395
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1395
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1394
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1394
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1389
# trigger sell
# broker close
# 2019-01-18, SELL CREATE, 1.14
# 2019-01-18, SELL EXECUTED, Price: 1.14, Cost: -34.17, Comm 0.00
# 2019-01-18, Close, 1.1395
# Custom Close called
# trigger close
# broker close
# 2019-01-18, BUY EXECUTED, Price: 1.14, Cost: -34.17, Comm 0.00
# 2019-01-18, OPERATION PROFIT, GROSS -1.86, NET -1.86
# Current Portfolio Value: 99993.58
# 2019-01-18, Close, 1.1391
# trigger sell
# broker close
# 2019-01-18, SELL CREATE, 1.14
# 2019-01-18, SELL EXECUTED, Price: 1.14, Cost: -34.17, Comm 0.00
# 2019-01-18, Close, 1.1396
# Custom Close called
# trigger close
# broker close
# 2019-01-18, BUY EXECUTED, Price: 1.14, Cost: -34.17, Comm 0.00
# 2019-01-18, OPERATION PROFIT, GROSS -1.32, NET -1.32
# Current Portfolio Value: 99992.26
# 2019-01-18, Close, 1.1398
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1407
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1405
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1403
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1398
# Custom Close called
# trigger close
# broker close
# 2019-01-18, Close, 1.1374
# trigger sell
# broker close
# 2019-01-18, SELL CREATE, 1.14
# 2019-01-18, SELL EXECUTED, Price: 1.14, Cost: -34.12, Comm 0.00
# 2019-01-18, Close, 1.1367
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1362
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1358
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1365
# trigger sell
# broker sell
# 2019-01-18, Close, 1.1370
# Custom Close called
# trigger close
# broker close
# 2019-01-18, BUY EXECUTED, Price: 1.14, Cost: -34.12, Comm 0.00
# 2019-01-18, OPERATION PROFIT, GROSS 1.38, NET 1.38
# Current Portfolio Value: 99993.64
# 2019-01-18, Close, 1.1365
# trigger sell
# broker close
# 2019-01-18, SELL CREATE, 1.14
# 2019-01-18, SELL EXECUTED, Price: 1.14, Cost: -34.09, Comm 0.00
# 2019-01-18, Close, 1.1361
# trigger sell
# broker sell
# 2019-01-20, Close, 1.1365
# trigger sell
# broker sell
# 2019-01-20, Close, 1.1365
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1374
# Custom Close called
# trigger close
# broker close
# 2019-01-21, BUY EXECUTED, Price: 1.14, Cost: -34.09, Comm 0.00
# 2019-01-21, OPERATION PROFIT, GROSS -2.79, NET -2.79
# Current Portfolio Value: 99990.85
# 2019-01-21, Close, 1.1376
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1377
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1375
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1379
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1378
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1380
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1385
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1375
# trigger sell
# broker close
# 2019-01-21, SELL CREATE, 1.14
# 2019-01-21, SELL EXECUTED, Price: 1.14, Cost: -34.12, Comm 0.00
# 2019-01-21, Close, 1.1371
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1377
# Custom Close called
# trigger close
# broker close
# 2019-01-21, BUY EXECUTED, Price: 1.14, Cost: -34.12, Comm 0.00
# 2019-01-21, OPERATION PROFIT, GROSS -0.75, NET -0.75
# Current Portfolio Value: 99990.10
# 2019-01-21, Close, 1.1369
# trigger sell
# broker close
# 2019-01-21, SELL CREATE, 1.14
# 2019-01-21, SELL EXECUTED, Price: 1.14, Cost: -34.11, Comm 0.00
# 2019-01-21, Close, 1.1368
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1361
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1364
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1363
# trigger sell
# broker sell
# 2019-01-21, Close, 1.1369
# Custom Close called
# trigger close
# broker close
# 2019-01-21, BUY EXECUTED, Price: 1.14, Cost: -34.11, Comm 0.00
# 2019-01-21, OPERATION PROFIT, GROSS -0.36, NET -0.36
# Current Portfolio Value: 99989.74
# 2019-01-21, Close, 1.1368
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1368
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1369
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1368
# Custom Close called
# trigger close
# broker close
# 2019-01-21, Close, 1.1366
# trigger sell
# broker close
# 2019-01-21, SELL CREATE, 1.14
# 2019-01-21, SELL EXECUTED, Price: 1.14, Cost: -34.10, Comm 0.00
# 2019-01-21, Close, 1.1369
# Custom Close called
# trigger close
# broker close
# 2019-01-21, BUY EXECUTED, Price: 1.14, Cost: -34.10, Comm 0.00
# 2019-01-21, OPERATION PROFIT, GROSS -1.17, NET -1.17
# Current Portfolio Value: 99988.57
# 2019-01-21, Close, 1.1369
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1368
# trigger sell
# broker close
# 2019-01-22, SELL CREATE, 1.14
# 2019-01-22, SELL EXECUTED, Price: 1.14, Cost: -34.10, Comm 0.00
# 2019-01-22, Close, 1.1370
# Custom Close called
# trigger close
# broker close
# 2019-01-22, BUY EXECUTED, Price: 1.14, Cost: -34.10, Comm 0.00
# 2019-01-22, OPERATION PROFIT, GROSS -0.51, NET -0.51
# Current Portfolio Value: 99988.06
# 2019-01-22, Close, 1.1370
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1362
# trigger sell
# broker close
# 2019-01-22, SELL CREATE, 1.14
# 2019-01-22, SELL EXECUTED, Price: 1.14, Cost: -34.09, Comm 0.00
# 2019-01-22, Close, 1.1358
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1357
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1354
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1353
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1361
# Custom Close called
# trigger close
# broker close
# 2019-01-22, BUY EXECUTED, Price: 1.14, Cost: -34.09, Comm 0.00
# 2019-01-22, OPERATION PROFIT, GROSS 0.54, NET 0.54
# Current Portfolio Value: 99988.60
# 2019-01-22, Close, 1.1361
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1362
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1358
# trigger sell
# broker close
# 2019-01-22, SELL CREATE, 1.14
# 2019-01-22, SELL EXECUTED, Price: 1.14, Cost: -34.08, Comm 0.00
# 2019-01-22, Close, 1.1355
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1345
# trigger sell
# broker sell
# 2019-01-22, Close, 1.1355
# Custom Close called
# trigger close
# broker close
# 2019-01-22, BUY EXECUTED, Price: 1.14, Cost: -34.08, Comm 0.00
# 2019-01-22, OPERATION PROFIT, GROSS 0.90, NET 0.90
# Current Portfolio Value: 99989.50
# 2019-01-22, Close, 1.1356
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1359
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1369
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1368
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1362
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1352
# trigger sell
# broker close
# 2019-01-22, SELL CREATE, 1.14
# 2019-01-22, SELL EXECUTED, Price: 1.14, Cost: -34.06, Comm 0.00
# 2019-01-22, Close, 1.1360
# Custom Close called
# trigger close
# broker close
# 2019-01-22, BUY EXECUTED, Price: 1.14, Cost: -34.06, Comm 0.00
# 2019-01-22, OPERATION PROFIT, GROSS -2.16, NET -2.16
# Current Portfolio Value: 99987.34
# 2019-01-22, Close, 1.1363
# Custom Close called
# trigger close
# broker close
# 2019-01-22, Close, 1.1363
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1364
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1365
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1365
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1364
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1366
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1368
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1371
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1365
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1362
# trigger sell
# broker close
# 2019-01-23, SELL CREATE, 1.14
# 2019-01-23, SELL EXECUTED, Price: 1.14, Cost: -34.09, Comm 0.00
# 2019-01-23, Close, 1.1356
# trigger sell
# broker sell
# 2019-01-23, Close, 1.1358
# trigger sell
# broker sell
# 2019-01-23, Close, 1.1365
# Custom Close called
# trigger close
# broker close
# 2019-01-23, BUY EXECUTED, Price: 1.14, Cost: -34.09, Comm 0.00
# 2019-01-23, OPERATION PROFIT, GROSS -0.90, NET -0.90
# Current Portfolio Value: 99986.44
# 2019-01-23, Close, 1.1366
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1354
# trigger sell
# broker close
# 2019-01-23, SELL CREATE, 1.14
# 2019-01-23, SELL EXECUTED, Price: 1.14, Cost: -34.06, Comm 0.00
# 2019-01-23, Close, 1.1363
# Custom Close called
# trigger close
# broker close
# 2019-01-23, BUY EXECUTED, Price: 1.14, Cost: -34.06, Comm 0.00
# 2019-01-23, OPERATION PROFIT, GROSS -2.40, NET -2.40
# Current Portfolio Value: 99984.04
# 2019-01-23, Close, 1.1379
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1389
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1393
# trigger buy
# broker close
# 2019-01-23, BUY CREATE, 1.14
# 2019-01-23, BUY EXECUTED, Price: 1.14, Cost: 34.18, Comm 0.00
# 2019-01-23, Close, 1.1387
# trigger buy
# broker buy
# 2019-01-23, Close, 1.1383
# trigger buy
# broker buy
# 2019-01-23, Close, 1.1382
# Custom Close called
# trigger close
# broker close
# 2019-01-23, SELL EXECUTED, Price: 1.14, Cost: 34.18, Comm 0.00
# 2019-01-23, OPERATION PROFIT, GROSS -2.97, NET -2.97
# Current Portfolio Value: 99981.07
# 2019-01-23, Close, 1.1381
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1380
# Custom Close called
# trigger close
# broker close
# 2019-01-23, Close, 1.1386
# trigger buy
# broker close
# 2019-01-23, BUY CREATE, 1.14
# 2019-01-24, BUY EXECUTED, Price: 1.14, Cost: 34.16, Comm 0.00
# 2019-01-24, Close, 1.1387
# trigger buy
# broker buy
# 2019-01-24, Close, 1.1387
# trigger buy
# broker buy
# 2019-01-24, Close, 1.1386
# trigger buy
# broker buy
# 2019-01-24, Close, 1.1388
# trigger buy
# broker buy
# 2019-01-24, Close, 1.1386
# Custom Close called
# trigger close
# broker close
# 2019-01-24, SELL EXECUTED, Price: 1.14, Cost: 34.16, Comm 0.00
# 2019-01-24, OPERATION PROFIT, GROSS 0.00, NET 0.00
# Current Portfolio Value: 99981.07
# 2019-01-24, Close, 1.1385
# Custom Close called
# trigger close
# broker close
# 2019-01-24, Close, 1.1380
# Custom Close called
# trigger close
# broker close
# 2019-01-24, Close, 1.1370
# Custom Close called
# trigger close
# broker close
# 2019-01-24, Close, 1.1365
# trigger sell
# broker close
# 2019-01-24, SELL CREATE, 1.14
# 2019-01-24, SELL EXECUTED, Price: 1.14, Cost: -34.09, Comm 0.00
# 2019-01-24, Close, 1.1347
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1344
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1346
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1340
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1335
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1378
# Custom Close called
# trigger close
# broker close
# 2019-01-24, BUY EXECUTED, Price: 1.14, Cost: -34.09, Comm 0.00
# 2019-01-24, OPERATION PROFIT, GROSS -3.93, NET -3.93
# Current Portfolio Value: 99977.14
# 2019-01-24, Close, 1.1354
# trigger sell
# broker close
# 2019-01-24, SELL CREATE, 1.14
# 2019-01-24, SELL EXECUTED, Price: 1.14, Cost: -34.06, Comm 0.00
# 2019-01-24, Close, 1.1321
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1299
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1304
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1299
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1308
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1302
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1302
# trigger sell
# broker sell
# 2019-01-24, Close, 1.1313
# Custom Close called
# trigger close
# broker close
# 2019-01-25, BUY EXECUTED, Price: 1.13, Cost: -34.06, Comm 0.00
# 2019-01-25, OPERATION PROFIT, GROSS 12.42, NET 12.42
# Current Portfolio Value: 99989.56
# 2019-01-25, Close, 1.1310
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1308
# trigger sell
# broker close
# 2019-01-25, SELL CREATE, 1.13
# 2019-01-25, SELL EXECUTED, Price: 1.13, Cost: -33.92, Comm 0.00
# 2019-01-25, Close, 1.1320
# Custom Close called
# trigger close
# broker close
# 2019-01-25, BUY EXECUTED, Price: 1.13, Cost: -33.92, Comm 0.00
# 2019-01-25, OPERATION PROFIT, GROSS -3.75, NET -3.75
# Current Portfolio Value: 99985.81
# 2019-01-25, Close, 1.1321
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1320
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1322
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1324
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1324
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1327
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1330
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1338
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1346
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1342
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1357
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1379
# Custom Close called
# trigger close
# broker close
# 2019-01-25, Close, 1.1397
# trigger buy
# broker close
# 2019-01-25, BUY CREATE, 1.14
# 2019-01-25, BUY EXECUTED, Price: 1.14, Cost: 34.19, Comm 0.00
# 2019-01-25, Close, 1.1406
# trigger buy
# broker buy
# 2019-01-25, Close, 1.1405
# trigger buy
# broker buy
# 2019-01-25, Close, 1.1407
# trigger buy
# broker buy
# 2019-01-25, Close, 1.1414
# trigger buy
# broker buy
# 2019-01-25, Close, 1.1415
# trigger buy
# broker buy
# 2019-01-25, Close, 1.1403
# Custom Close called
# trigger close
# broker close
# 2019-01-27, SELL EXECUTED, Price: 1.14, Cost: 34.19, Comm 0.00
# 2019-01-27, OPERATION PROFIT, GROSS 0.99, NET 0.99
# Current Portfolio Value: 99986.80
# 2019-01-27, Close, 1.1409
# trigger buy
# broker close
# 2019-01-27, BUY CREATE, 1.14
# 2019-01-27, BUY EXECUTED, Price: 1.14, Cost: 34.23, Comm 0.00
# 2019-01-27, Close, 1.1413
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1411
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1415
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1414
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1419
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1419
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1412
# Custom Close called
# trigger close
# broker close
# 2019-01-28, SELL EXECUTED, Price: 1.14, Cost: 34.23, Comm 0.00
# 2019-01-28, OPERATION PROFIT, GROSS 0.84, NET 0.84
# Current Portfolio Value: 99987.64
# 2019-01-28, Close, 1.1408
# Custom Close called
# trigger close
# broker close
# 2019-01-28, Close, 1.1406
# Custom Close called
# trigger close
# broker close
# 2019-01-28, Close, 1.1401
# Custom Close called
# trigger close
# broker close
# 2019-01-28, Close, 1.1408
# trigger buy
# broker close
# 2019-01-28, BUY CREATE, 1.14
# 2019-01-28, BUY EXECUTED, Price: 1.14, Cost: 34.22, Comm 0.00
# 2019-01-28, Close, 1.1414
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1407
# Custom Close called
# trigger close
# broker close
# 2019-01-28, SELL EXECUTED, Price: 1.14, Cost: 34.22, Comm 0.00
# 2019-01-28, OPERATION PROFIT, GROSS -0.39, NET -0.39
# Current Portfolio Value: 99987.25
# 2019-01-28, Close, 1.1412
# trigger buy
# broker close
# 2019-01-28, BUY CREATE, 1.14
# 2019-01-28, BUY EXECUTED, Price: 1.14, Cost: 34.24, Comm 0.00
# 2019-01-28, Close, 1.1417
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1427
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1436
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1437
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1434
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1435
# trigger buy
# broker buy
# 2019-01-28, Close, 1.1428
# Custom Close called
# trigger close
# broker close
# 2019-01-28, SELL EXECUTED, Price: 1.14, Cost: 34.24, Comm 0.00
# 2019-01-28, OPERATION PROFIT, GROSS 4.83, NET 4.83
# Current Portfolio Value: 99992.08
# 2019-01-28, Close, 1.1428
# Custom Close called
# trigger close
# broker close
# 2019-01-28, Close, 1.1427
# Custom Close called
# trigger close
# broker close
# 2019-01-28, Close, 1.1427
# Custom Close called
# trigger close
# broker close
# 2019-01-28, Close, 1.1429
# trigger buy
# broker close
# 2019-01-28, BUY CREATE, 1.14
# 2019-01-29, BUY EXECUTED, Price: 1.14, Cost: 34.29, Comm 0.00
# 2019-01-29, Close, 1.1426
# Custom Close called
# trigger close
# broker close
# 2019-01-29, SELL EXECUTED, Price: 1.14, Cost: 34.29, Comm 0.00
# 2019-01-29, OPERATION PROFIT, GROSS -0.87, NET -0.87
# Current Portfolio Value: 99991.21
# 2019-01-29, Close, 1.1425
# Custom Close called
# trigger close
# broker close
# 2019-01-29, Close, 1.1430
# trigger buy
# broker close
# 2019-01-29, BUY CREATE, 1.14
# 2019-01-29, BUY EXECUTED, Price: 1.14, Cost: 34.29, Comm 0.00
# 2019-01-29, Close, 1.1429
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1432
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1433
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1435
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1435
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1441
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1441
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1440
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1436
# Custom Close called
# trigger close
# broker close
# 2019-01-29, SELL EXECUTED, Price: 1.14, Cost: 34.29, Comm 0.00
# 2019-01-29, OPERATION PROFIT, GROSS 1.59, NET 1.59
# Current Portfolio Value: 99992.80
# 2019-01-29, Close, 1.1425
# Custom Close called
# trigger close
# broker close
# 2019-01-29, Close, 1.1426
# Custom Close called
# trigger close
# broker close
# 2019-01-29, Close, 1.1425
# Custom Close called
# trigger close
# broker close
# 2019-01-29, Close, 1.1416
# Custom Close called
# trigger close
# broker close
# 2019-01-29, Close, 1.1424
# Custom Close called
# trigger close
# broker close
# 2019-01-29, Close, 1.1428
# Custom Close called
# trigger close
# broker close
# 2019-01-29, Close, 1.1424
# Custom Close called
# trigger close
# broker close
# 2019-01-29, Close, 1.1428
# trigger buy
# broker close
# 2019-01-29, BUY CREATE, 1.14
# 2019-01-29, BUY EXECUTED, Price: 1.14, Cost: 34.28, Comm 0.00
# 2019-01-29, Close, 1.1433
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1431
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1434
# trigger buy
# broker buy
# 2019-01-29, Close, 1.1435
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1435
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1439
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1440
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1437
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1440
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1445
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1435
# Custom Close called
# trigger close
# broker close
# 2019-01-30, SELL EXECUTED, Price: 1.14, Cost: 34.28, Comm 0.00
# 2019-01-30, OPERATION PROFIT, GROSS 2.10, NET 2.10
# Current Portfolio Value: 99994.90
# 2019-01-30, Close, 1.1431
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1432
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1430
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1429
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1434
# trigger buy
# broker close
# 2019-01-30, BUY CREATE, 1.14
# 2019-01-30, BUY EXECUTED, Price: 1.14, Cost: 34.30, Comm 0.00
# 2019-01-30, Close, 1.1431
# Custom Close called
# trigger close
# broker close
# 2019-01-30, SELL EXECUTED, Price: 1.14, Cost: 34.30, Comm 0.00
# 2019-01-30, OPERATION PROFIT, GROSS -0.84, NET -0.84
# Current Portfolio Value: 99994.06
# 2019-01-30, Close, 1.1425
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1414
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1425
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1417
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1419
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1417
# Custom Close called
# trigger close
# broker close
# 2019-01-30, Close, 1.1492
# trigger buy
# broker close
# 2019-01-30, BUY CREATE, 1.15
# 2019-01-30, BUY EXECUTED, Price: 1.15, Cost: 34.48, Comm 0.00
# 2019-01-30, Close, 1.1481
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1479
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1481
# trigger buy
# broker buy
# 2019-01-30, Close, 1.1485
# trigger buy
# broker buy
# 2019-01-31, Close, 1.1488
# trigger buy
# broker buy
# 2019-01-31, Close, 1.1493
# trigger buy
# broker buy
# 2019-01-31, Close, 1.1503
# trigger buy
# broker buy
# 2019-01-31, Close, 1.1502
# trigger buy
# broker buy
# 2019-01-31, Close, 1.1503
# trigger buy
# broker buy
# 2019-01-31, Close, 1.1505
# trigger buy
# broker buy
# 2019-01-31, Close, 1.1500
# trigger buy
# broker buy
# 2019-01-31, Close, 1.1496
# Custom Close called
# trigger close
# broker close
# 2019-01-31, SELL EXECUTED, Price: 1.15, Cost: 34.48, Comm 0.00
# 2019-01-31, OPERATION PROFIT, GROSS 1.17, NET 1.17
# Current Portfolio Value: 99995.23
# 2019-01-31, Close, 1.1491
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1484
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1477
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1487
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1493
# trigger buy
# broker close
# 2019-01-31, BUY CREATE, 1.15
# 2019-01-31, BUY EXECUTED, Price: 1.15, Cost: 34.48, Comm 0.00
# 2019-01-31, Close, 1.1494
# trigger buy
# broker buy
# 2019-01-31, Close, 1.1477
# Custom Close called
# trigger close
# broker close
# 2019-01-31, SELL EXECUTED, Price: 1.15, Cost: 34.48, Comm 0.00
# 2019-01-31, OPERATION PROFIT, GROSS -4.65, NET -4.65
# Current Portfolio Value: 99990.58
# 2019-01-31, Close, 1.1475
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1453
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1450
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1444
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1444
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1445
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1447
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1446
# Custom Close called
# trigger close
# broker close
# 2019-01-31, Close, 1.1448
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1448
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1442
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1442
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1442
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1442
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1437
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1442
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1448
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1448
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1466
# trigger buy
# broker close
# 2019-02-01, BUY CREATE, 1.15
# 2019-02-01, BUY EXECUTED, Price: 1.15, Cost: 34.40, Comm 0.00
# 2019-02-01, Close, 1.1467
# trigger buy
# broker buy
# 2019-02-01, Close, 1.1470
# trigger buy
# broker buy
# 2019-02-01, Close, 1.1469
# trigger buy
# broker buy
# 2019-02-01, Close, 1.1474
# trigger buy
# broker buy
# 2019-02-01, Close, 1.1476
# trigger buy
# broker buy
# 2019-02-01, Close, 1.1468
# Custom Close called
# trigger close
# broker close
# 2019-02-01, SELL EXECUTED, Price: 1.15, Cost: 34.40, Comm 0.00
# 2019-02-01, OPERATION PROFIT, GROSS 0.60, NET 0.60
# Current Portfolio Value: 99991.18
# 2019-02-01, Close, 1.1473
# trigger buy
# broker close
# 2019-02-01, BUY CREATE, 1.15
# 2019-02-01, BUY EXECUTED, Price: 1.15, Cost: 34.42, Comm 0.00
# 2019-02-01, Close, 1.1468
# Custom Close called
# trigger close
# broker close
# 2019-02-01, SELL EXECUTED, Price: 1.15, Cost: 34.42, Comm 0.00
# 2019-02-01, OPERATION PROFIT, GROSS -1.29, NET -1.29
# Current Portfolio Value: 99989.89
# 2019-02-01, Close, 1.1460
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1460
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1459
# Custom Close called
# trigger close
# broker close
# 2019-02-01, Close, 1.1455
# Custom Close called
# trigger close
# broker close
# 2019-02-03, Close, 1.1456
# Custom Close called
# trigger close
# broker close
# 2019-02-03, Close, 1.1454
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1456
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1458
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1453
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1448
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1442
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1443
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1444
# trigger sell
# broker close
# 2019-02-04, SELL CREATE, 1.14
# 2019-02-04, SELL EXECUTED, Price: 1.14, Cost: -34.33, Comm 0.00
# 2019-02-04, Close, 1.1442
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1451
# Custom Close called
# trigger close
# broker close
# 2019-02-04, BUY EXECUTED, Price: 1.15, Cost: -34.33, Comm 0.00
# 2019-02-04, OPERATION PROFIT, GROSS -2.04, NET -2.04
# Current Portfolio Value: 99987.85
# 2019-02-04, Close, 1.1445
# trigger sell
# broker close
# 2019-02-04, SELL CREATE, 1.14
# 2019-02-04, SELL EXECUTED, Price: 1.14, Cost: -34.34, Comm 0.00
# 2019-02-04, Close, 1.1446
# Custom Close called
# trigger close
# broker close
# 2019-02-04, BUY EXECUTED, Price: 1.14, Cost: -34.34, Comm 0.00
# 2019-02-04, OPERATION PROFIT, GROSS -0.42, NET -0.42
# Current Portfolio Value: 99987.43
# 2019-02-04, Close, 1.1452
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1448
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1449
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1426
# trigger sell
# broker close
# 2019-02-04, SELL CREATE, 1.14
# 2019-02-04, SELL EXECUTED, Price: 1.14, Cost: -34.28, Comm 0.00
# 2019-02-04, Close, 1.1429
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1438
# Custom Close called
# trigger close
# broker close
# 2019-02-04, BUY EXECUTED, Price: 1.14, Cost: -34.28, Comm 0.00
# 2019-02-04, OPERATION PROFIT, GROSS -3.39, NET -3.39
# Current Portfolio Value: 99984.04
# 2019-02-04, Close, 1.1431
# trigger sell
# broker close
# 2019-02-04, SELL CREATE, 1.14
# 2019-02-04, SELL EXECUTED, Price: 1.14, Cost: -34.29, Comm 0.00
# 2019-02-04, Close, 1.1432
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1431
# trigger sell
# broker sell
# 2019-02-04, Close, 1.1434
# Custom Close called
# trigger close
# broker close
# 2019-02-04, BUY EXECUTED, Price: 1.14, Cost: -34.29, Comm 0.00
# 2019-02-04, OPERATION PROFIT, GROSS -0.96, NET -0.96
# Current Portfolio Value: 99983.08
# 2019-02-04, Close, 1.1435
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1435
# Custom Close called
# trigger close
# broker close
# 2019-02-04, Close, 1.1435
# Custom Close called
# trigger close
# broker close
# 2019-02-05, Close, 1.1436
# Custom Close called
# trigger close
# broker close
# 2019-02-05, Close, 1.1438
# Custom Close called
# trigger close
# broker close
# 2019-02-05, Close, 1.1439
# Custom Close called
# trigger close
# broker close
# 2019-02-05, Close, 1.1433
# trigger sell
# broker close
# 2019-02-05, SELL CREATE, 1.14
# 2019-02-05, SELL EXECUTED, Price: 1.14, Cost: -34.30, Comm 0.00
# 2019-02-05, Close, 1.1432
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1434
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1433
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1425
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1414
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1419
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1417
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1421
# Custom Close called
# trigger close
# broker close
# 2019-02-05, BUY EXECUTED, Price: 1.14, Cost: -34.30, Comm 0.00
# 2019-02-05, OPERATION PROFIT, GROSS 3.54, NET 3.54
# Current Portfolio Value: 99986.62
# 2019-02-05, Close, 1.1421
# trigger sell
# broker close
# 2019-02-05, SELL CREATE, 1.14
# 2019-02-05, SELL EXECUTED, Price: 1.14, Cost: -34.26, Comm 0.00
# 2019-02-05, Close, 1.1429
# Custom Close called
# trigger close
# broker close
# 2019-02-05, BUY EXECUTED, Price: 1.14, Cost: -34.26, Comm 0.00
# 2019-02-05, OPERATION PROFIT, GROSS -2.49, NET -2.49
# Current Portfolio Value: 99984.13
# 2019-02-05, Close, 1.1414
# trigger sell
# broker close
# 2019-02-05, SELL CREATE, 1.14
# 2019-02-05, SELL EXECUTED, Price: 1.14, Cost: -34.24, Comm 0.00
# 2019-02-05, Close, 1.1406
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1405
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1409
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1413
# Custom Close called
# trigger close
# broker close
# 2019-02-05, BUY EXECUTED, Price: 1.14, Cost: -34.24, Comm 0.00
# 2019-02-05, OPERATION PROFIT, GROSS 0.63, NET 0.63
# Current Portfolio Value: 99984.76
# 2019-02-05, Close, 1.1409
# trigger sell
# broker close
# 2019-02-05, SELL CREATE, 1.14
# 2019-02-05, SELL EXECUTED, Price: 1.14, Cost: -34.23, Comm 0.00
# 2019-02-05, Close, 1.1413
# Custom Close called
# trigger close
# broker close
# 2019-02-05, BUY EXECUTED, Price: 1.14, Cost: -34.23, Comm 0.00
# 2019-02-05, OPERATION PROFIT, GROSS -0.96, NET -0.96
# Current Portfolio Value: 99983.80
# 2019-02-05, Close, 1.1405
# trigger sell
# broker close
# 2019-02-05, SELL CREATE, 1.14
# 2019-02-05, SELL EXECUTED, Price: 1.14, Cost: -34.22, Comm 0.00
# 2019-02-05, Close, 1.1404
# trigger sell
# broker sell
# 2019-02-05, Close, 1.1409
# Custom Close called
# trigger close
# broker close
# 2019-02-06, BUY EXECUTED, Price: 1.14, Cost: -34.22, Comm 0.00
# 2019-02-06, OPERATION PROFIT, GROSS -0.99, NET -0.99
# Current Portfolio Value: 99982.81
# 2019-02-06, Close, 1.1406
# trigger sell
# broker close
# 2019-02-06, SELL CREATE, 1.14
# 2019-02-06, SELL EXECUTED, Price: 1.14, Cost: -34.22, Comm 0.00
# 2019-02-06, Close, 1.1401
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1403
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1398
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1401
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1397
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1390
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1389
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1391
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1388
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1397
# Custom Close called
# trigger close
# broker close
# 2019-02-06, BUY EXECUTED, Price: 1.14, Cost: -34.22, Comm 0.00
# 2019-02-06, OPERATION PROFIT, GROSS 2.94, NET 2.94
# Current Portfolio Value: 99985.75
# 2019-02-06, Close, 1.1385
# trigger sell
# broker close
# 2019-02-06, SELL CREATE, 1.14
# 2019-02-06, SELL EXECUTED, Price: 1.14, Cost: -34.15, Comm 0.00
# 2019-02-06, Close, 1.1392
# Custom Close called
# trigger close
# broker close
# 2019-02-06, BUY EXECUTED, Price: 1.14, Cost: -34.15, Comm 0.00
# 2019-02-06, OPERATION PROFIT, GROSS -2.13, NET -2.13
# Current Portfolio Value: 99983.62
# 2019-02-06, Close, 1.1387
# trigger sell
# broker close
# 2019-02-06, SELL CREATE, 1.14
# 2019-02-06, SELL EXECUTED, Price: 1.14, Cost: -34.16, Comm 0.00
# 2019-02-06, Close, 1.1383
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1377
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1380
# trigger sell
# broker sell
# 2019-02-06, Close, 1.1375
# ...
# 2019-03-21, Close, 1.1406
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1388
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1392
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1385
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1392
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1371
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1361
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1352
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1353
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1353
# trigger sell
# broker close
# 2019-03-21, SELL CREATE, 1.14
# 2019-03-21, SELL EXECUTED, Price: 1.14, Cost: -34.06, Comm 0.00
# 2019-03-21, Close, 1.1367
# Custom Close called
# trigger close
# broker close
# 2019-03-21, BUY EXECUTED, Price: 1.14, Cost: -34.06, Comm 0.00
# 2019-03-21, OPERATION PROFIT, GROSS -4.14, NET -4.14
# Current Portfolio Value: 99969.07
# 2019-03-21, Close, 1.1373
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1373
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1376
# Custom Close called
# trigger close
# broker close
# 2019-03-21, Close, 1.1374
# Custom Close called
# trigger close
# broker close
# 2019-03-22, Close, 1.1367
# Custom Close called
# trigger close
# broker close
# 2019-03-22, Close, 1.1376
# Custom Close called
# trigger close
# broker close
# 2019-03-22, Close, 1.1374
# Custom Close called
# trigger close
# broker close
# 2019-03-22, Close, 1.1375
# Custom Close called
# trigger close
# broker close
# 2019-03-22, Close, 1.1378
# Custom Close called
# trigger close
# broker close
# 2019-03-22, Close, 1.1377
# Custom Close called
# trigger close
# broker close
# 2019-03-22, Close, 1.1380
# trigger buy
# broker close
# 2019-03-22, BUY CREATE, 1.14
# 2019-03-22, BUY EXECUTED, Price: 1.14, Cost: 34.14, Comm 0.00
# 2019-03-22, Close, 1.1388
# trigger buy
# broker buy
# 2019-03-22, Close, 1.1303
# trigger sell
# broker buy
# 2019-03-22, Close, 1.1305
# trigger sell
# broker buy
# 2019-03-22, Close, 1.1309
# trigger sell
# broker buy
# 2019-03-22, Close, 1.1299
# trigger sell
# broker buy
# 2019-03-22, Close, 1.1305
# trigger sell
# broker buy
# 2019-03-22, Close, 1.1305
# trigger sell
# broker buy
# 2019-03-22, Close, 1.1279
# trigger sell
# broker buy
# 2019-03-22, Close, 1.1283
# trigger sell
# broker buy
# 2019-03-22, Close, 1.1284
# trigger sell
# broker buy
# 2019-03-22, Close, 1.1297
# Custom Close called
# trigger close
# broker close
# 2019-03-22, SELL EXECUTED, Price: 1.13, Cost: 34.14, Comm 0.00
# 2019-03-22, OPERATION PROFIT, GROSS -24.90, NET -24.90
# Current Portfolio Value: 99944.17
# 2019-03-22, Close, 1.1294
# Custom Close called
# trigger close
# broker close
# 2019-03-22, Close, 1.1297
# Custom Close called
# trigger close
# broker close
# 2019-03-22, Close, 1.1300
# Custom Close called
# trigger close
# broker close
# 2019-03-24, Close, 1.1294
# trigger sell
# broker close
# 2019-03-24, SELL CREATE, 1.13
# 2019-03-24, SELL EXECUTED, Price: 1.13, Cost: -33.88, Comm 0.00
# 2019-03-24, Close, 1.1296
# trigger sell
# broker sell
# 2019-03-24, Close, 1.1296
# trigger sell
# broker sell
# 2019-03-25, Close, 1.1290
# trigger sell
# broker sell
# 2019-03-25, Close, 1.1295
# Custom Close called
# trigger close
# broker close
# 2019-03-25, BUY EXECUTED, Price: 1.13, Cost: -33.88, Comm 0.00
# 2019-03-25, OPERATION PROFIT, GROSS -0.27, NET -0.27
# Current Portfolio Value: 99943.90
# 2019-03-25, Close, 1.1296
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1299
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1298
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1303
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1303
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1309
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1308
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1320
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1313
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1309
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1318
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1316
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1321
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1321
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1312
# trigger sell
# broker close
# 2019-03-25, SELL CREATE, 1.13
# 2019-03-25, SELL EXECUTED, Price: 1.13, Cost: -33.93, Comm 0.00
# 2019-03-25, Close, 1.1317
# Custom Close called
# trigger close
# broker close
# 2019-03-25, BUY EXECUTED, Price: 1.13, Cost: -33.93, Comm 0.00
# 2019-03-25, OPERATION PROFIT, GROSS -1.44, NET -1.44
# Current Portfolio Value: 99942.46
# 2019-03-25, Close, 1.1312
# trigger sell
# broker close
# 2019-03-25, SELL CREATE, 1.13
# 2019-03-25, SELL EXECUTED, Price: 1.13, Cost: -33.94, Comm 0.00
# 2019-03-25, Close, 1.1315
# Custom Close called
# trigger close
# broker close
# 2019-03-25, BUY EXECUTED, Price: 1.13, Cost: -33.94, Comm 0.00
# 2019-03-25, OPERATION PROFIT, GROSS -0.81, NET -0.81
# Current Portfolio Value: 99941.65
# 2019-03-25, Close, 1.1312
# trigger sell
# broker close
# 2019-03-25, SELL CREATE, 1.13
# 2019-03-25, SELL EXECUTED, Price: 1.13, Cost: -33.94, Comm 0.00
# 2019-03-25, Close, 1.1313
# Custom Close called
# trigger close
# broker close
# 2019-03-25, BUY EXECUTED, Price: 1.13, Cost: -33.94, Comm 0.00
# 2019-03-25, OPERATION PROFIT, GROSS -0.39, NET -0.39
# Current Portfolio Value: 99941.26
# 2019-03-25, Close, 1.1314
# Custom Close called
# trigger close
# broker close
# 2019-03-25, Close, 1.1315
# Custom Close called
# trigger close
# broker close
# 2019-03-26, Close, 1.1318
# Custom Close called
# trigger close
# broker close
# 2019-03-26, Close, 1.1316
# Custom Close called
# trigger close
# broker close
# 2019-03-26, Close, 1.1317
# Custom Close called
# trigger close
# broker close
# 2019-03-26, Close, 1.1316
# Custom Close called
# trigger close
# broker close
# 2019-03-26, Close, 1.1311
# trigger sell
# broker close
# 2019-03-26, SELL CREATE, 1.13
# 2019-03-26, SELL EXECUTED, Price: 1.13, Cost: -33.93, Comm 0.00
# 2019-03-26, Close, 1.1307
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1308
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1313
# Custom Close called
# trigger close
# broker close
# 2019-03-26, BUY EXECUTED, Price: 1.13, Cost: -33.93, Comm 0.00
# 2019-03-26, OPERATION PROFIT, GROSS -0.45, NET -0.45
# Current Portfolio Value: 99940.81
# 2019-03-26, Close, 1.1307
# trigger sell
# broker close
# 2019-03-26, SELL CREATE, 1.13
# 2019-03-26, SELL EXECUTED, Price: 1.13, Cost: -33.92, Comm 0.00
# 2019-03-26, Close, 1.1317
# Custom Close called
# trigger close
# broker close
# 2019-03-26, BUY EXECUTED, Price: 1.13, Cost: -33.92, Comm 0.00
# 2019-03-26, OPERATION PROFIT, GROSS -3.12, NET -3.12
# Current Portfolio Value: 99937.69
# 2019-03-26, Close, 1.1323
# Custom Close called
# trigger close
# broker close
# 2019-03-26, Close, 1.1311
# trigger sell
# broker close
# 2019-03-26, SELL CREATE, 1.13
# 2019-03-26, SELL EXECUTED, Price: 1.13, Cost: -33.93, Comm 0.00
# 2019-03-26, Close, 1.1288
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1285
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1298
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1279
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1288
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1283
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1277
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1269
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1265
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1270
# trigger sell
# broker sell
# 2019-03-26, Close, 1.1275
# Custom Close called
# trigger close
# broker close
# 2019-03-26, BUY EXECUTED, Price: 1.13, Cost: -33.93, Comm 0.00
# 2019-03-26, OPERATION PROFIT, GROSS 10.56, NET 10.56
# Current Portfolio Value: 99948.25
# 2019-03-26, Close, 1.1274
# trigger sell
# broker close
# 2019-03-26, SELL CREATE, 1.13
# 2019-03-27, SELL EXECUTED, Price: 1.13, Cost: -33.82, Comm 0.00
# 2019-03-27, Close, 1.1267
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1256
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1257
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1253
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1258
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1257
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1266
# Custom Close called
# trigger close
# broker close
# 2019-03-27, BUY EXECUTED, Price: 1.13, Cost: -33.82, Comm 0.00
# 2019-03-27, OPERATION PROFIT, GROSS 2.31, NET 2.31
# Current Portfolio Value: 99950.56
# 2019-03-27, Close, 1.1252
# trigger sell
# broker close
# 2019-03-27, SELL CREATE, 1.13
# 2019-03-27, SELL EXECUTED, Price: 1.13, Cost: -33.76, Comm 0.00
# 2019-03-27, Close, 1.1276
# Custom Close called
# trigger close
# broker close
# 2019-03-27, BUY EXECUTED, Price: 1.13, Cost: -33.76, Comm 0.00
# 2019-03-27, OPERATION PROFIT, GROSS -7.05, NET -7.05
# Current Portfolio Value: 99943.51
# 2019-03-27, Close, 1.1280
# Custom Close called
# trigger close
# broker close
# 2019-03-27, Close, 1.1278
# Custom Close called
# trigger close
# broker close
# 2019-03-27, Close, 1.1281
# Custom Close called
# trigger close
# broker close
# 2019-03-27, Close, 1.1271
# Custom Close called
# trigger close
# broker close
# 2019-03-27, Close, 1.1259
# trigger sell
# broker close
# 2019-03-27, SELL CREATE, 1.13
# 2019-03-27, SELL EXECUTED, Price: 1.13, Cost: -33.78, Comm 0.00
# 2019-03-27, Close, 1.1252
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1251
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1263
# Custom Close called
# trigger close
# broker close
# 2019-03-27, BUY EXECUTED, Price: 1.13, Cost: -33.78, Comm 0.00
# 2019-03-27, OPERATION PROFIT, GROSS -1.35, NET -1.35
# Current Portfolio Value: 99942.16
# 2019-03-27, Close, 1.1254
# trigger sell
# broker close
# 2019-03-27, SELL CREATE, 1.13
# 2019-03-27, SELL EXECUTED, Price: 1.13, Cost: -33.76, Comm 0.00
# 2019-03-27, Close, 1.1264
# Custom Close called
# trigger close
# broker close
# 2019-03-27, BUY EXECUTED, Price: 1.13, Cost: -33.76, Comm 0.00
# 2019-03-27, OPERATION PROFIT, GROSS -3.03, NET -3.03
# Current Portfolio Value: 99939.13
# 2019-03-27, Close, 1.1251
# trigger sell
# broker close
# 2019-03-27, SELL CREATE, 1.13
# 2019-03-27, SELL EXECUTED, Price: 1.13, Cost: -33.75, Comm 0.00
# 2019-03-27, Close, 1.1243
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1251
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1249
# trigger sell
# broker sell
# 2019-03-27, Close, 1.1252
# Custom Close called
# trigger close
# broker close
# 2019-03-28, BUY EXECUTED, Price: 1.13, Cost: -33.75, Comm 0.00
# 2019-03-28, OPERATION PROFIT, GROSS -0.15, NET -0.15
# Current Portfolio Value: 99938.98
# 2019-03-28, Close, 1.1248
# trigger sell
# broker close
# 2019-03-28, SELL CREATE, 1.12
# 2019-03-28, SELL EXECUTED, Price: 1.12, Cost: -33.74, Comm 0.00
# 2019-03-28, Close, 1.1246
# trigger sell
# broker sell
# 2019-03-28, Close, 1.1255
# Custom Close called
# trigger close
# broker close
# 2019-03-28, BUY EXECUTED, Price: 1.13, Cost: -33.74, Comm 0.00
# 2019-03-28, OPERATION PROFIT, GROSS -2.13, NET -2.13
# Current Portfolio Value: 99936.85
# 2019-03-28, Close, 1.1255
# Custom Close called
# trigger close
# broker close
# 2019-03-28, Close, 1.1255
# Custom Close called
# trigger close
# broker close
# 2019-03-28, Close, 1.1257
# Custom Close called
# trigger close
# broker close
# 2019-03-28, Close, 1.1256
# Custom Close called
# trigger close
# broker close
# 2019-03-28, Close, 1.1238
# trigger sell
# broker close
# 2019-03-28, SELL CREATE, 1.12
# 2019-03-28, SELL EXECUTED, Price: 1.12, Cost: -33.71, Comm 0.00
# 2019-03-28, Close, 1.1252
# Custom Close called
# trigger close
# broker close
# 2019-03-28, BUY EXECUTED, Price: 1.13, Cost: -33.71, Comm 0.00
# 2019-03-28, OPERATION PROFIT, GROSS -4.20, NET -4.20
# Current Portfolio Value: 99932.65
# 2019-03-28, Close, 1.1255
# Custom Close called
# trigger close
# broker close
# 2019-03-28, Close, 1.1252
# trigger sell
# broker close
# 2019-03-28, SELL CREATE, 1.13
# 2019-03-28, SELL EXECUTED, Price: 1.13, Cost: -33.76, Comm 0.00
# 2019-03-28, Close, 1.1226
# trigger sell
# broker sell
# 2019-03-28, Close, 1.1221
# trigger sell
# broker sell
# 2019-03-28, Close, 1.1217
# trigger sell
# broker sell
# 2019-03-28, Close, 1.1234
# Custom Close called
# trigger close
# broker close
# 2019-03-28, BUY EXECUTED, Price: 1.12, Cost: -33.76, Comm 0.00
# 2019-03-28, OPERATION PROFIT, GROSS 5.52, NET 5.52
# Current Portfolio Value: 99938.17
# 2019-03-28, Close, 1.1236
# Custom Close called
# trigger close
# broker close
# 2019-03-28, Close, 1.1227
# trigger sell
# broker close
# 2019-03-28, SELL CREATE, 1.12
# 2019-03-28, SELL EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-28, Close, 1.1236
# Custom Close called
# trigger close
# broker close
# 2019-03-28, BUY EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-28, OPERATION PROFIT, GROSS -2.49, NET -2.49
# Current Portfolio Value: 99935.68
# 2019-03-28, Close, 1.1227
# trigger sell
# broker close
# 2019-03-28, SELL CREATE, 1.12
# 2019-03-28, SELL EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-28, Close, 1.1223
# trigger sell
# broker sell
# 2019-03-28, Close, 1.1221
# trigger sell
# broker sell
# 2019-03-28, Close, 1.1226
# Custom Close called
# trigger close
# broker close
# 2019-03-28, BUY EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-28, OPERATION PROFIT, GROSS 0.06, NET 0.06
# Current Portfolio Value: 99935.74
# 2019-03-28, Close, 1.1228
# Custom Close called
# trigger close
# broker close
# 2019-03-28, Close, 1.1230
# Custom Close called
# trigger close
# broker close
# 2019-03-29, Close, 1.1232
# Custom Close called
# trigger close
# broker close
# 2019-03-29, Close, 1.1227
# trigger sell
# broker close
# 2019-03-29, SELL CREATE, 1.12
# 2019-03-29, SELL EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-29, Close, 1.1230
# Custom Close called
# trigger close
# broker close
# 2019-03-29, BUY EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-29, OPERATION PROFIT, GROSS -0.87, NET -0.87
# Current Portfolio Value: 99934.87
# 2019-03-29, Close, 1.1228
# trigger sell
# broker close
# 2019-03-29, SELL CREATE, 1.12
# 2019-03-29, SELL EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-29, Close, 1.1230
# Custom Close called
# trigger close
# broker close
# 2019-03-29, BUY EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-29, OPERATION PROFIT, GROSS -0.54, NET -0.54
# Current Portfolio Value: 99934.33
# 2019-03-29, Close, 1.1234
# Custom Close called
# trigger close
# broker close
# 2019-03-29, Close, 1.1235
# Custom Close called
# trigger close
# broker close
# 2019-03-29, Close, 1.1230
# trigger sell
# broker close
# 2019-03-29, SELL CREATE, 1.12
# 2019-03-29, SELL EXECUTED, Price: 1.12, Cost: -33.69, Comm 0.00
# 2019-03-29, Close, 1.1230
# trigger sell
# broker sell
# 2019-03-29, Close, 1.1211
# trigger sell
# broker sell
# 2019-03-29, Close, 1.1223
# trigger sell
# broker sell
# 2019-03-29, Close, 1.1230
# Custom Close called
# trigger close
# broker close
# 2019-03-29, BUY EXECUTED, Price: 1.12, Cost: -33.69, Comm 0.00
# 2019-03-29, OPERATION PROFIT, GROSS 0.12, NET 0.12
# Current Portfolio Value: 99934.45
# 2019-03-29, Close, 1.1232
# Custom Close called
# trigger close
# broker close
# 2019-03-29, Close, 1.1235
# Custom Close called
# trigger close
# broker close
# 2019-03-29, Close, 1.1227
# trigger sell
# broker close
# 2019-03-29, SELL CREATE, 1.12
# 2019-03-29, SELL EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-29, Close, 1.1227
# trigger sell
# broker sell
# 2019-03-29, Close, 1.1225
# trigger sell
# broker sell
# 2019-03-29, Close, 1.1221
# trigger sell
# broker sell
# 2019-03-29, Close, 1.1215
# trigger sell
# broker sell
# 2019-03-29, Close, 1.1217
# trigger sell
# broker sell
# 2019-03-29, Close, 1.1218
# trigger sell
# broker sell
# 2019-03-31, Close, 1.1228
# Custom Close called
# trigger close
# broker close
# 2019-03-31, BUY EXECUTED, Price: 1.12, Cost: -33.68, Comm 0.00
# 2019-03-31, OPERATION PROFIT, GROSS -0.18, NET -0.18
# Current Portfolio Value: 99934.27
# 2019-03-31, Close, 1.1222
# trigger sell
# broker close
# 2019-03-31, SELL CREATE, 1.12
# 2019-03-31, SELL EXECUTED, Price: 1.12, Cost: -33.67, Comm 0.00
# 2019-03-31, Close, 1.1223
# Custom Close called
# trigger close
# broker close
# 2019-04-01, BUY EXECUTED, Price: 1.12, Cost: -33.67, Comm 0.00
# 2019-04-01, OPERATION PROFIT, GROSS -0.42, NET -0.42
# Current Portfolio Value: 99933.85
# 2019-04-01, Close, 1.1228
# Custom Close called
# trigger close
# broker close
# Final Portfolio Value: 99933.85
# Final Portfolio Value: $99933.85000000006
# P/L: $-66.14999999993597
